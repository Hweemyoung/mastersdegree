# %%
import numpy as np
import pandas as pd
from db_handler import DBHandler
from matplotlib import pyplot as plt
from scipy import stats
from datetime import datetime, timedelta
from calendar import monthrange
from scopus_handler import ScopusHandler
# %matplotlib inline

# %% [markdown]
# YTScore만 이동(x축으로만)

# %%
df3 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2014_comp.csv")
df3_sources = pd.read_csv("scopus/source_2013_comp.csv", header=0)
scopus_2014_comp = ScopusHandler(df3, df3_sources, "scopus_videos_2014_comp", title="2014_comp", verbose=False)
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-weighed-sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 9598	After: 9336
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.

# %% [markdown]
# 피인용수 값도 이동(x,y축 둘다 이동) <- y축의 의미가 있나?

# %%
df3 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2014_comp.csv")
df3_sources = pd.read_csv("scopus/source_2013_comp.csv", header=0)
scopus_2014_comp = ScopusHandler(df3, df3_sources, "scopus_videos_2014_comp", title="2014_comp", verbose=False)
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-weighed-sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 9598	After: 9336
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.

# %% [markdown]
# x축으로만 이동해서 직선 만들기

# %%
import numpy as np
import pandas as pd
from db_handler import DBHandler
from matplotlib import pyplot as plt
from scipy import stats
from datetime import datetime, timedelta
from calendar import monthrange
from scopus_handler import ScopusHandler
# %matplotlib inline

# %%
df3 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2014_comp.csv")
df3_sources = pd.read_csv("scopus/source_2013_comp.csv", header=0)
scopus_2014_comp = ScopusHandler(df3, df3_sources, "scopus_videos_2014_comp", title="2014_comp", verbose=False)
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True, xlim=(0, 7))
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-weighed-sum", label_by="content-simple", regression=True, log_scale=True, xlim=(0, 7))
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 9598	After: 9336
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.

# %%
df1 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2019_comp.csv")
df1_sources = pd.read_csv("scopus/source_2018_comp.csv", header=0)
scopus_2019_comp = ScopusHandler(df1, df1_sources, "scopus_videos_2019_comp", title="2019_comp", verbose=False)
scopus_2019_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True, xlim=(0, 7))
scopus_2019_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-weighed-sum", label_by="content-simple", regression=True, log_scale=True, xlim=(0, 7))
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 14533	After: 14330
# [+]Target DOIs: 64
# 	[-]DOI 10.1109/TRO.2019.2899269: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2898738: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.
# [+]Target DOIs: 64
# 	[-]DOI 10.1109/TRO.2019.2899269: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2898738: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.

# %%
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-weighed-sum", label_by="content-simple", regression=True, log_scale=True, xlim=(0, 7))
scopus_2019_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-weighed-sum", label_by="content-simple", regression=True, log_scale=True, xlim=(0, 7))
# Out:
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.
# [+]Target DOIs: 64
# 	[-]DOI 10.1109/TRO.2019.2899269: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2898738: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.

# %%
df4 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2014_life.csv")
df4_sources = pd.read_csv("scopus/source_2013_life.csv", header=0)
scopus_2014_life = ScopusHandler(df4, df4_sources, "scopus_videos_2014_life", title="2014_life", verbose=False)
scopus_2014_life.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
scopus_2014_life.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-weighed-sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 7816	After: 7717
# [+]Target DOIs: 78
# [+]Target DOIs: 78

# %% [markdown]
# 2019 LIFE

# %%
df2 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2019_life.csv")
df2_sources = pd.read_csv("scopus/source_2018_life.csv", header=0)
scopus_2019_life = ScopusHandler(df2, df2_sources, "scopus_videos_2019_life", title="2019_life", verbose=False)
_where = ("idx", ScopusHandler._tup_idx_2019_life, "in")
scopus_2019_life.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", where=_where, regression=True, log_scale=True)
scopus_2019_life.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-weighed-sum", label_by="content-simple", where=_where, regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 7742	After: 7735
# [+]Target DOIs: 59
# 	[-]DOI 10.3847/2041-8213/ab1b75: not found in df_scopus.
# 	[-]DOI 10.3847/2041-8213/ab1b75: Either YTscore or paper meter is None.
# 	[-]DOI 10.3847/2041-8213/ab1b75: Either YTscore or paper meter is None.
# [+]Target DOIs: 59
# 	[-]DOI 10.3847/2041-8213/ab1b75: not found in df_scopus.
# 	[-]DOI 10.3847/2041-8213/ab1b75: Either YTscore or paper meter is None.
# 	[-]DOI 10.3847/2041-8213/ab1b75: Either YTscore or paper meter is None.

# %% [markdown]
# b값으로 인해서 음수로 튀어나가버리는데?
