# %%
import numpy as np
import pandas as pd
from db_handler import DBHandler
from matplotlib import pyplot as plt
from scipy import stats
from datetime import datetime, timedelta
from calendar import monthrange
# %matplotlib inline
from scopus_handler import ScopusHandler

# %%
df3 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2014_comp.csv")
df3_sources = pd.read_csv("scopus/source_2013_comp.csv", header=0)
scopus_2014_comp = ScopusHandler(df3, df3_sources, "scopus_videos_2014_comp", verbose=False)
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
scopus_2014_comp.model_metrics(paper_metric="AAS", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 9598	After: 9336
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.
# [+]Target DOIs: 102
# 	[-]DOI 10.1109/TSE.2013.48: not found in df_scopus.
# 	[-]DOI 10.1109/TITS.2013.2291241: not found in df_scopus.
# 	[-]DOI 10.1109/TSE.2013.58: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2014.2302477: not found in df_scopus.
# 	[-]DOI 10.1109/TKDE.2013.88: not found in df_scopus.
# 	[-]DOI 10.1109/TITS.2013.2294723: not found in df_scopus.
# 	[-]DOI 10.1371/journal.pcbi.1003439: not found in df_scopus.
# 	[-]DOI 10.1177/0278364913519148: not found in df_scopus.
# 	[-]DOI 10.1109/TKDE.2013.89: not found in df_scopus.
# 	[-]DOI 10.1109/TKDE.2013.41: not found in df_scopus.
# 	[-]DOI 10.1109/TPDS.2013.299: not found in df_scopus.
# 	[-]DOI 10.1016/j.imavis.2014.02.003: not found in df_scopus.
# 	[-]DOI 10.1109/TPDS.2013.122: not found in df_scopus.
# 	[-]DOI 10.1109/TKDE.2013.123: not found in df_scopus.
# 	[-]DOI 10.1109/TKDE.2013.11: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2013.2283927: not found in df_scopus.
# 	[-]DOI 10.1109/MIC.2014.19: not found in df_scopus.
# 	[-]DOI 10.1109/TVT.2013.2281213: not found in df_scopus.
# 	[-]DOI 10.1109/TKDE.2013.124: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285242: not found in df_scopus.
# 	[-]DOI 10.1109/TVT.2014.2310394: not found in df_scopus.
# 	[-]DOI 10.1109/JBHI.2013.2282827: not found in df_scopus.
# 	[-]DOI 10.1177/0278364914522141: not found in df_scopus.
# 	[-]DOI 10.1109/TKDE.2013.109: not found in df_scopus.
# 	[-]DOI 10.1109/TPDS.2013.132: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2013.2280831: not found in df_scopus.
# 	[-]DOI 10.1109/TSC.2013.18: not found in df_scopus.
# 	[-]DOI 10.1016/j.compedu.2013.12.002: not found in df_scopus.
# 	[-]DOI 10.1016/j.cviu.2013.12.006: not found in df_scopus.
# 	[-]DOI 10.1109/TPDS.2013.261: not found in df_scopus.
# 	[-]DOI 10.1109/TKDE.2013.134: not found in df_scopus.
# 	[-]DOI 10.1109/TSC.2013.3: not found in df_scopus.
# 	[-]DOI 10.1109/TSC.2013.29: not found in df_scopus.
# 	[-]DOI 10.1109/TSE.2013.2297712: not found in df_scopus.
# 	[-]DOI 10.1016/j.knosys.2013.12.005: not found in df_scopus.
# 	[-]DOI 10.1177/0278364912473169: not found in df_scopus.
# 	[-]DOI 10.1109/TII.2014.2305641: not found in df_scopus.
# 	[-]DOI 10.1109/TIFS.2013.2291220: not found in df_scopus.
# 	[-]DOI 10.1109/TII.2014.2306329: not found in df_scopus.
# 	[-]DOI 10.1371/journal.pcbi.1003446: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1177/0278364913509858: not found in df_scopus.
# 	[-]DOI 10.1109/TSE.2013.48: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TITS.2013.2291241: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TSE.2013.58: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2014.2302477: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TKDE.2013.88: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TITS.2013.2294723: Either YTscore or paper meter is None.
# 	[-]DOI 10.1371/journal.pcbi.1003439: Either YTscore or paper meter is None.
# 	[-]DOI 10.1177/0278364913519148: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TKDE.2013.89: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TKDE.2013.41: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TPDS.2013.299: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.imavis.2014.02.003: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TPDS.2013.122: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TKDE.2013.123: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TKDE.2013.11: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2013.2283927: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/MIC.2014.19: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVT.2013.2281213: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TKDE.2013.124: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285242: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVT.2014.2310394: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/JBHI.2013.2282827: Either YTscore or paper meter is None.
# 	[-]DOI 10.1177/0278364914522141: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TKDE.2013.109: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TPDS.2013.132: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2013.2280831: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TSC.2013.18: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.compedu.2013.12.002: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.cviu.2013.12.006: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TPDS.2013.261: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TKDE.2013.134: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TSC.2013.3: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TSC.2013.29: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TSE.2013.2297712: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.knosys.2013.12.005: Either YTscore or paper meter is None.
# 	[-]DOI 10.1177/0278364912473169: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TII.2014.2305641: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TIFS.2013.2291220: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TII.2014.2306329: Either YTscore or paper meter is None.
# 	[-]DOI 10.1371/journal.pcbi.1003446: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.
# 	[-]DOI 10.1177/0278364913509858: Either YTscore or paper meter is None.

# %%
df4 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2014_life.csv")
df4_sources = pd.read_csv("scopus/source_2013_life.csv", header=0)
scopus_2014_life = ScopusHandler(df4, df4_sources, "scopus_videos_2014_life", verbose=False)
scopus_2014_life.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
scopus_2014_life.model_metrics(paper_metric="AAS", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 7816	After: 7717
# [+]Target DOIs: 78
# [+]Target DOIs: 78
# 	[-]DOI 10.1039/c3ee43099e: not found in df_scopus.
# 	[-]DOI 10.1039/c4gc00049h: not found in df_scopus.
# 	[-]DOI 10.1039/c3gc41503a: not found in df_scopus.
# 	[-]DOI 10.1111/brv.12055: not found in df_scopus.
# 	[-]DOI 10.1039/c3ee43099e: Either YTscore or paper meter is None.
# 	[-]DOI 10.1039/c4gc00049h: Either YTscore or paper meter is None.
# 	[-]DOI 10.1039/c3gc41503a: Either YTscore or paper meter is None.
# 	[-]DOI 10.1111/brv.12055: Either YTscore or paper meter is None.

# %%
df1 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2019_comp.csv")
df1_sources = pd.read_csv("scopus/source_2018_comp.csv", header=0)
scopus_2019_comp = ScopusHandler(df1, df1_sources, "scopus_videos_2019_comp", verbose=False)
scopus_2019_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
scopus_2019_comp.model_metrics(paper_metric="AAS", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 14533	After: 14330
# [+]Target DOIs: 64
# 	[-]DOI 10.1109/TRO.2019.2899269: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2898738: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.
# [+]Target DOIs: 64
# 	[-]DOI 10.1016/j.ejor.2018.04.039: not found in df_scopus.
# 	[-]DOI 10.25300/MISQ/2019/14812: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2018.2864817: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2899187: not found in df_scopus.
# 	[-]DOI 10.1109/TII.2018.2870662: not found in df_scopus.
# 	[-]DOI 10.1016/j.adhoc.2018.11.004: not found in df_scopus.
# 	[-]DOI 10.1145/3241737: not found in df_scopus.
# 	[-]DOI 10.1145/3298981: not found in df_scopus.
# 	[-]DOI 10.1109/MCOM.2018.1701370: not found in df_scopus.
# 	[-]DOI 10.1016/j.compedu.2018.09.012: not found in df_scopus.
# 	[-]DOI 10.1016/j.ins.2018.08.062: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2018.2868804: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2898742: not found in df_scopus.
# 	[-]DOI 10.1016/j.robot.2019.01.013: not found in df_scopus.
# 	[-]DOI 10.1109/TMECH.2019.2909081: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2019.2897858: not found in df_scopus.
# 	[-]DOI 10.1177/0278364918796267: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2018.2864509: not found in df_scopus.
# 	[-]DOI 10.1109/TII.2018.2847736: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2019.2899269: not found in df_scopus.
# 	[-]DOI 10.1016/j.compind.2019.03.004: not found in df_scopus.
# 	[-]DOI 10.1016/j.isprsjprs.2019.02.014: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2018.2887356: not found in df_scopus.
# 	[-]DOI 10.1016/j.ejor.2018.10.005: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2898738: not found in df_scopus.
# 	[-]DOI 10.1109/THMS.2019.2895753: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2018.2808969: not found in df_scopus.
# 	[-]DOI 10.1016/j.ejor.2018.04.039: Either YTscore or paper meter is None.
# 	[-]DOI 10.25300/MISQ/2019/14812: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2018.2864817: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2899187: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TII.2018.2870662: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.adhoc.2018.11.004: Either YTscore or paper meter is None.
# 	[-]DOI 10.1145/3241737: Either YTscore or paper meter is None.
# 	[-]DOI 10.1145/3298981: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/MCOM.2018.1701370: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.compedu.2018.09.012: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.ins.2018.08.062: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2018.2868804: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898742: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.robot.2019.01.013: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TMECH.2019.2909081: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2019.2897858: Either YTscore or paper meter is None.
# 	[-]DOI 10.1177/0278364918796267: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2018.2864509: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TII.2018.2847736: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.compind.2019.03.004: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.isprsjprs.2019.02.014: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2018.2887356: Either YTscore or paper meter is None.
# 	[-]DOI 10.1016/j.ejor.2018.10.005: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/THMS.2019.2895753: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TVCG.2018.2808969: Either YTscore or paper meter is None.

# %%
df2 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2019_life.csv")
df2_sources = pd.read_csv("scopus/source_2018_life.csv", header=0)
scopus_2019_life = ScopusHandler(df2, df2_sources, "scopus_videos_2019_life", verbose=False)
scopus_2019_life.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", where=("idx", scopus_2019_life._tup_idx_2019_life, "in"), label_by="content-simple", regression=True, log_scale=True)
scopus_2019_life.model_metrics(paper_metric="AAS", video_metric="viewCount", method="sum", where=("idx", scopus_2019_life._tup_idx_2019_life, "in"), label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 7742	After: 7735
# [+]Target DOIs: 59
# 	[-]DOI 10.3847/2041-8213/ab1b75: not found in df_scopus.
# 	[-]DOI 10.3847/2041-8213/ab1b75: Either YTscore or paper meter is None.
# [+]Target DOIs: 59
# 	[-]DOI 10.3847/2041-8213/ab2599: not found in df_scopus.
# 	[-]DOI 10.3847/2041-8213/ab2599: Either YTscore or paper meter is None.

# %%
import numpy as np
import pandas as pd
from db_handler import DBHandler
from matplotlib import pyplot as plt
from scipy import stats
from datetime import datetime, timedelta
from calendar import monthrange
# %matplotlib inline
from scopus_handler import ScopusHandler

# %%
df3 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2014_comp.csv")
df3_sources = pd.read_csv("scopus/source_2013_comp.csv", header=0)
scopus_2014_comp = ScopusHandler(df3, df3_sources, "scopus_videos_2014_comp", verbose=False)
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 9598	After: 9336
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.

# %%
scopus_2014_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Target DOIs: 102
# 	[-]DOI 10.1021/ct401105x: not found in df_scopus.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: not found in df_scopus.
# 	[-]DOI 10.1021/ct401105x: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TNNLS.2013.2285928: Either YTscore or paper meter is None.

# %%
df1 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_2019_comp.csv")
df1_sources = pd.read_csv("scopus/source_2018_comp.csv", header=0)
scopus_2019_comp = ScopusHandler(df1, df1_sources, "scopus_videos_2019_comp", verbose=False)
scopus_2019_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
# scopus_2019_comp.model_metrics(paper_metric="AAS", video_metric="viewCount", method="sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 14533	After: 14330
# [+]Target DOIs: 64
# 	[-]DOI 10.1109/TVCG.2019.2898738: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2019.2899269: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.

# %%
dict_content_calib_coef = {
    "paper_explanation": 1.2,
    "paper_supplementary": 0.8,
    "paper_reference": 0.9,
    "news": 0.3,
    "Mixed": 1.0,
}
scopus_2019_comp.model_metrics(paper_metric="Cited by", video_metric="viewCount", method="calibrated-sum", label_by="content-simple", regression=True, log_scale=True)
# Out:
# [+]Target DOIs: 64
# 	[-]DOI 10.1109/TVCG.2019.2898738: not found in df_scopus.
# 	[-]DOI 10.1109/TRO.2019.2899269: not found in df_scopus.
# 	[-]DOI 10.1109/TVCG.2019.2898738: Either YTscore or paper meter is None.
# 	[-]DOI 10.1109/TRO.2019.2899269: Either YTscore or paper meter is None.
