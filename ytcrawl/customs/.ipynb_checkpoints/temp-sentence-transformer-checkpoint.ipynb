# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import pandas as pd

embedder = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')

# %%
e1 = embedder.encode(["I am a man."])

# %%
e2 = embedder.encode(["I am a man. You are a woman."])
e2_1 = embedder.encode(["I am a man. You are a woman. "])

# %%
e1.reshape(-1).shape
# Out:
# (768,)

# %%
e2 == e2_1
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True]])

# %%
# Corpus with example sentences
corpus = ['A man is eating food.',
          'A man is eating a piece of bread.',
          'A man is eating pasta.',
          'The girl is carrying a baby.',
          'The baby is carried by the woman',
          'A man is riding a horse.',
          'A man is riding a white horse on an enclosed ground.',
          'A monkey is playing drums.',
          'Someone in a gorilla costume is playing a set of drums.',
          'A cheetah is running behind its prey.',
          'A cheetah chases prey on across a field.'
          ]
corpus_embeddings = embedder.encode(corpus)

# Perform kmean clustering
num_clusters = 5
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = [[] for i in range(num_clusters)]
for sentence_id, cluster_id in enumerate(cluster_assignment):
    clustered_sentences[cluster_id].append(corpus[sentence_id])

for i, cluster in enumerate(clustered_sentences):
    print("Cluster ", i+1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# ['The girl is carrying a baby.', 'The baby is carried by the woman']
#
# Cluster  2
# ['A man is eating food.', 'A man is eating a piece of bread.', 'A man is eating pasta.']
#
# Cluster  3
# ['A man is riding a horse.', 'A man is riding a white horse on an enclosed ground.']
#
# Cluster  4
# ['A monkey is playing drums.', 'Someone in a gorilla costume is playing a set of drums.']
#
# Cluster  5
# ['A cheetah is running behind its prey.', 'A cheetah chases prey on across a field.']

# %%
import pandas as pd

# %%
df_scopus = pd.read_csv("scopus/scopus_math+comp_top5perc_1901-1906.csv")
# df_scopus = df_scopus[df_scopus["Abstract"] != "[No abstract available]"]

# %%
target_scopus = df_scopus.sample(n=100)
list_abs = list(target_scopus["Abstract"])
list_abs = list(map(lambda abs: abs.split("©")[0], list_abs))

list_titles = list(target_scopus["Title"])

# %%
corpus_embeddings = embedder.encode(list_abs)
# Perform kmean clustering
num_clusters = 5
clustering_model = KMeans(n_clusters=num_clusters)
cluster_assignment = clustering_model.fit_predict(corpus_embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a4a308e4155a> in <module>
# ----> 1 corpus_embeddings = embedder.encode(list_abs)
#       2 # Perform kmean clustering
#       3 num_clusters = 5
#       4 clustering_model = KMeans(n_clusters=num_clusters)
#       5 cluster_assignment = clustering_model.fit_predict(corpus_embeddings)
#
# NameError: name 'embedder' is not defined

# %%
cluster_assignment
# Out:
# array([2, 1, 2, 2, 1, 1, 1, 1, 4, 4, 2, 1, 1, 1, 4, 1, 4, 1, 1, 1, 2, 1,
#        1, 2, 2, 2, 4, 1, 1, 4, 4, 3, 2, 2, 4, 3, 3, 2, 1, 1, 4, 1, 3, 4,
#        4, 3, 1, 1, 1, 1, 4, 2, 1, 1, 2, 3, 1, 1, 1, 1, 1, 1, 2, 4, 4, 2,
#        1, 1, 1, 4, 4, 4, 1, 1, 1, 2, 1, 1, 2, 4, 4, 1, 0, 1, 4, 2, 4, 4,
#        2, 0, 1, 4, 4, 0, 3, 4, 1, 1, 0, 4], dtype=int32)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
corpus_pca = pca.fit_transform(corpus_embeddings)
# corpus_label = pca.predict(corpus_embeddings)

clustered_abs = [[] for i in range(num_clusters)]
clustered_embeddings = [[] for i in range(num_clusters)]
clustered_pca = [[] for i in range(num_clusters)]
clustered_titles = [[] for i in range(num_clusters)]

for sentence_id, cluster_id in enumerate(cluster_assignment):
    clustered_abs[cluster_id].append(list_abs[sentence_id])
    clustered_embeddings[cluster_id].append(corpus_embeddings[sentence_id])
    clustered_pca[cluster_id].append(corpus_pca[sentence_id])
    clustered_titles[cluster_id].append(list_titles[sentence_id])

for i, cluster in enumerate(clustered_titles):
    print("Cluster ", i+1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# ['Intestinal Microbiota in Early Life and Its Implications on Childhood Health', 'gFACs: Gene Filtering, Analysis, and Conversion to Unify Genome Annotations Across Alignment and Gene Prediction Frameworks', 'A generic deep convolutional neural network framework for prediction of receptor-ligand interactions-NetPhosPan: Application to kinase phosphorylation prediction', 'Near-optimal lower bounds on the threshold degree and sign-rank of AC0']
#
# Cluster  2
# ['Image-text dual neural network with decision strategy for small-sample image classification', 'LPTD: Achieving lightweight and privacy-preserving truth discovery in CIoT', 'Direction of Arrival Estimation for Reverberant Speech Based on Enhanced Decomposition of the Direct Sound', 'Adaptive fuzzy decentralized control for a class of MIMO large-scale nonlinear state delay systems with unmodeled dynamics subject to unknown input saturation and infinite number of actuator failures', 'A Data-Centric Cognitive Gateway with Distributed MIMO for Future Smart Homes', 'Mathematical model studies of the comprehensive generation of major and minor phyllotactic patterns in plants with a predominant focus on orixate phyllotaxis', 'A center-driven image set partition algorithm for efficient structure from motion', 'Enhanced Localization of Robotic Capsule Endoscopes Using Positron Emission Markers and Rigid-Body Transformation', 'Dynamic difficulty awareness training for continuous emotion prediction', 'Density-sensitive Robust Fuzzy Kernel Principal Component Analysis technique', 'Machine learning approaches for non-intrusive load monitoring: from qualitative to quantitative comparation', 'Massively parallel quantum computer simulator, eleven years later', 'Biases in feature selection with missing data', 'Joint Channel Estimation and Tx/Rx I/Q Imbalance Compensation for GFDM Systems', 'New Modality: Emoji Challenges in Prediction, Anticipation, and Retrieval', 'Precise Power Delay Profiling with Commodity Wi-Fi', 'Reliability Analysis of Next-Generation CBTC Data Communication Systems', 'Ordinal Constraint Binary Coding for Approximate Nearest Neighbor Search', 'Avoiding hERG-liability in drug design via synergetic combinations of different (Q)SAR methodologies and data sources: A case study in an industrial setting', 'Image co-saliency detection and co-segmentation via progressive joint optimization', 'Secure Wideband Beamforming Design for Two-Way MIMO Relaying Systems', 'Deep reinforcement learning optimal transmission policy for communication systems with energy harvesting and adaptive mqam', 'Learning recurrent residual regressors for single image super-resolution', 'A non-singleton type-2 fuzzy neural network with adaptive secondary membership for high dimensional applications', 'Performance of ODROID-MC1 for scientific flow problems', 'Trust management for secure cognitive radio vehicular ad hoc networks', 'Enhanced disturbance rejection control based test rocket control system design and validation', 'Engineering security-aware control applications for data authentication in smart industrial cyber–physical systems', 'AP-initiated multi-user transmissions in IEEE 802.11ax WLANs', 'Particle swarm optimization for network-based data classification', 'Relation extraction using distant supervision: A survey', 'Vibrational resonance in a scale-free network with different coupling schemes', 'A Novel Perspective on Multiple Access in 5G Network: Framework and Solutions', 'Progressive color transfer with dense semantic correspondences', 'Coupling Between Brain Structures During Visual and Auditory Working Memory Tasks', 'Robust and large-scale convolution through stochastic-based processing without multipliers', 'Two bifurcation routes to multiple chaotic coexistence in an inertial two-neural system with time delay', 'Tunable and reconfigurable mechanical transmission-line metamaterials via direct active feedback control', 'Review of classical dimensionality reduction and sample selection methods for large-scale data processing', 'On approximating the covering radius and finding dense lattice subspaces', 'Deep Cooperative Sensing: Cooperative Spectrum Sensing Based on Convolutional Neural Networks', 'Damping identification and localisation via Layer Method: Experimental application to a vehicle chassis focused on shock absorbers effects', 'A New Enhanced Energy-Detector-Based FM-DCSK UWB System for Tactile Internet', 'Fully distributed co ...
#
# Cluster  3
# ['Modeling visual performance differences ‘around’ the visual field: A computational observer approach', 'Reverse time migration of acoustic waves for imaging based defects detection for concrete and CFST structures', 'A survey on multithreading alternatives for soft error fault tolerance', 'Multibody model based estimation of multiple loads and strain field on a vehicle suspension system', 'A Method for Automatically Recreating the Horizontal Alignment Geometry of Existing Railways', 'Equivalent Legendre polynomials: Numerical integration of discontinuous functions in the finite element methods', 'Mechanical properties in double pulse resistance spot welding of Q&P 980 steel', 'Self-tuning stochastic resonance energy harvesting for rotating systems under modulated noise and its application to smart tires', 'Random field simulation over curved surfaces: Applications to computational structural mechanics', 'Screen-Shooting Resilient Watermarking', 'A phase-field formulation for dynamic cohesive fracture', 'Point stabilization control method for WIP vehicles based on motion planning', 'A unified framework for M-estimation based robust Kalman smoothing', 'Visualization of bubble formation in porous media', 'Eddy current induced dynamic deformation behaviors of aluminum alloy during EMF: Modeling and quantitative characterization', 'A Soft Retraction System for Surgery Based on Ferromagnetic Materials and Granular Jamming', 'Fixed pole based modeling and simulation schemes for fractional order systems', 'Homogenization-based stiffness optimization and projection of 2D coated structures with orthotropic infill', 'Weak feature enhancement in machinery fault diagnosis using empirical wavelet transform and an improved adaptive bistable stochastic resonance']
#
# Cluster  4
# ['Rotational energy harvesting using bi-stability and frequency up-conversion for low-power sensing applications: Theoretical modelling and experimental validation', 'Introductory overview: Optimization using evolutionary algorithms and other metaheuristics', 'Estimating manufacturing electricity costs by simulating dependence between production parameters', 'A pilot empirical study of applying a usability technique in an open source software project', 'Flexible time-of-use tariff with dynamic demand using artificial bee colony with transferred memory scheme', 'Analysis of ergodic rate for transmit antenna selection in low-resolution ADC systems', 'Coalitional game-based cost optimization of energy portfolio in smart grid communities']
#
# Cluster  5
# ['A new method for probabilistic linguistic multi-attribute group decision making: Application to the selection of financial technologies', 'Looking forward: The role of hope in information system continuance', 'Seeded transfer learning for regression problems with deep learning', 'Dynamic Graph Co-Matching for Unsupervised Video-Based Person Re-Identification', 'Online cluster validity indices for performance monitoring of streaming data clustering', 'On the use of evolutionary time series analysis for segmenting paleoclimate data', 'An adaptive large neighborhood search metaheuristic for the vehicle routing problem with drones', 'Multiagent Rendezvous with Shortest Distance to Convex Regions with Empty Intersection: Algorithms and Experiments', 'A framework of cloud service selection with criteria interactions', 'A novel Intrusion Detection System for Vehicular Ad Hoc Networks (VANETs) based on differences of traffic flow and position', 'Request delay-based pricing for proactive caching: A stackelberg game approach', 'Semi-supervised and active learning through Manifold Reciprocal kNN Graph for image retrieval', 'Artificial Intelligence Paradigm for Customer Experience Management in Next-Generation Networks: Challenges and Perspectives', 'Towards a big data framework for analyzing social media content', 'Impact of capacity fluctuation on throughput performance for semiconductor wafer fabrication', "Straight from the horse's mouth: Founders’ perspectives on achieving ‘traction’ in digital start-ups", 'Congestion analysis of unsignalized intersections: The impact of impatience and Markov platooning', 'How does strategic alignment affect firm performance? The roles of information technology investment and environmental uncertainty1', 'Constructing continuities in virtual work environments: A multiple case study of two firms with differing degrees of virtuality', 'Graph kernel based link prediction for signed social networks', 'A Unified Framework for Community Detection and Network Representation Learning', 'Bringing compassion into information systems research: A research agenda and call to action', 'Learning analytics in collaborative learning supported by Slack: From the perspective of engagement', 'Optimal procurement and production planning for multi-product multi-stage production under yield uncertainty', 'Multi-Modal and Multi-Domain Embedding Learning for Fashion Retrieval and Analysis', 'Differential evolution with underestimation-based multimutation strategy']

# %%
clustering_model.labels_ # c=
# Out:
# array([2, 1, 2, 2, 1, 1, 1, 1, 4, 4, 2, 1, 1, 1, 4, 1, 4, 1, 1, 1, 2, 1,
#        1, 2, 2, 2, 4, 1, 1, 4, 4, 3, 2, 2, 4, 3, 3, 2, 1, 1, 4, 1, 3, 4,
#        4, 3, 1, 1, 1, 1, 4, 2, 1, 1, 2, 3, 1, 1, 1, 1, 1, 1, 2, 4, 4, 2,
#        1, 1, 1, 4, 4, 4, 1, 1, 1, 2, 1, 1, 2, 4, 4, 1, 0, 1, 4, 2, 4, 4,
#        2, 0, 1, 4, 4, 0, 3, 4, 1, 1, 0, 4], dtype=int32)

# %%
# clustered_pca
corpus_pca
# Out:
# array([[-2.18078092e-01,  3.57382369e+00],
#        [ 6.31221235e-01, -1.41943789e+00],
#        [-4.58765602e+00,  2.50443053e+00],
#        [-1.19893515e+00,  6.78967178e-01],
#        [ 1.85429049e+00, -2.07495522e+00],
#        [-3.51731062e+00,  2.97986060e-01],
#        [-2.34024596e+00, -1.74819016e+00],
#        [-5.48442975e-02, -1.98884642e+00],
#        [ 4.20421076e+00, -1.15638506e+00],
#        [ 4.04424286e+00,  9.03796971e-01],
#        [-2.90055633e+00,  1.40583026e+00],
#        [-3.30561489e-01,  3.08043170e+00],
#        [-1.42019463e+00,  4.28838402e-01],
#        [-1.58229721e+00, -1.78978240e+00],
#        [ 1.09625614e+00,  3.75627786e-01],
#        [-4.40512896e-01, -3.91158819e-01],
#        [ 2.09296250e+00, -8.16160202e-01],
#        [ 3.42907095e+00,  1.01444654e-01],
#        [-2.99181724e+00, -1.54767418e+00],
#        [ 6.10353231e-01,  2.07950425e+00],
#        [-1.32793653e+00, -4.29389954e+00],
#        [ 3.63409781e+00, -2.17239165e+00],
#        [-3.02912140e+00,  2.74330473e+00],
#        [ 1.99427593e+00, -2.41477227e+00],
#        [ 1.97225606e+00,  2.21768236e+00],
#        [-5.58750534e+00,  9.33262110e-01],
#        [ 2.46664596e+00, -4.32821989e-01],
#        [-9.45977047e-02, -1.64547908e+00],
#        [ 4.51650858e+00, -1.74978495e+00],
#        [ 2.35704231e+00,  3.11554027e+00],
#        [ 1.26130295e+00, -1.67604136e+00],
#        [ 2.33971739e+00, -8.19421053e-01],
#        [ 5.42065811e+00, -7.21561074e-01],
#        [-1.93305469e+00, -7.81571940e-02],
#        [ 1.37917891e-01, -1.76413131e+00],
#        [-4.87628841e+00, -2.27785930e-01],
#        [ 4.34836715e-01,  1.45565999e+00]], dtype=float32)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(corpus_pca[:, 0], corpus_pca[:, 1], c=clustering_model.labels_)
plt.show()

# %% [markdown]
# 임베딩을 KMeans클러스터 후 PCA 변환을 plot해도 의미를 알 기 힘듦... 클러스터 간 겹치는 부분이 많네... 당연한가? <- 임베딩을 PCA 변환 후 Kmeans클러스터 플롯하면 더 의미가 보이겠지? 그것도 당연하네. 바운더리가 확실하니

# %% [markdown]
# 클러스터 수를 줄여서 적당한 바운더리를 찾자!

# %%
import numpy as np
import pandas as pd
from db_handler import DBHandler
from matplotlib import pyplot as plt
from scipy import stats
from datetime import datetime, timedelta
from calendar import monthrange
# %matplotlib inline

from scopus_handler import ScopusHandler

df1 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_math+comp_top5perc_1901-1906.csv")
df1_sources = pd.read_csv("scopus/source-results-math_cs-citescore-2018.csv", header=0)
# df2 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_math+comp_top5perc_1701-1706.csv")

df3 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_math+comp_top5perc_1401-1406.csv")
df3_sources = pd.read_csv("scopus/source-results-math_cs-citescore-2013.csv", header=0)
# df3_sources = pd.read_csv("scopus/")

# df1 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_life+earch_top60_1901-1906.csv")
# df2 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_math+comp_top5perc_1701-1706.csv")
# df3 = pd.read_csv("/home/hweem/git/mastersdegree/ytcrawl/customs/scopus/scopus_life+earch_top60_1401-1406.csv")
print(len(df1), len(df3))

df1 = df1.drop_duplicates(subset=["DOI"])
# df2 = df2.drop_duplicates(subset=["DOI"])
df3 = df3.drop_duplicates(subset=["DOI"])
print(len(df1), len(df3))
# Out:
# 14533 9598
# 14330 9336

# %%
scopus_2019_life = ScopusHandler(df1, df1_sources, "scopus_videos_2019_comp")
# Out:
# [+]Duplicates have been dropped from df_scopus.	Before: 14330	After: 14330

# %%
scopus_2019_life.cluster_scopus(target_column="Abstract", num_clusters=3)
# Out:
# [+]Assigning new embedder instance.
# 	Command set: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`
# 	sql: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`;
# # Total DOIs: 14330	# DOIs w/ videos: 61	Ratio: 0.004
# # Total videos: 79	# Target videos: 77	Ratio: 0.975
# # Total subjects: 46	# subjects w/ videos: 22	Ratio: 0.478
# # Total journals: 133	# journals w/ videos: 36	Ratio: 0.271
# # Total elements in plot: 61
# Cluster 1(N=15)
# ['Assessing binge-watching behaviors: Development and validation of the “Watching TV Series Motives” and “Binge-watching Engagement and Symptoms” questionnaires', 'Smartphones reduce smiles between strangers', 'A manifesto for future generation cloud computing: Research directions for the next decade', 'Social media data and post-disaster recovery', 'The Internet and Facebook Usage on Academic Distraction of College Students', 'Applying learning analytics to students’ interaction in business simulation games. The usefulness of learning analytics to know what students really learn', 'Locomotion in virtual reality for room scale tracked areas', 'Girls’ video gaming behaviour and undergraduate degree selection: A secondary data analysis approach', 'Latent goal models for dynamic strategic interaction', 'Digitization of music: Consumer adoption amidst piracy, unbundling, and rebundling', 'Visual Analysis of Aneurysm Data using Statistical Graphics', 'Ten simple rules towards healthier research labs', 'Deep full-body motion network for a soft wearable motion sensing suit', 'Computational Deglutition: Using Signal- and Image-Processing Methods to Understand Swallowing and Associated Disorders [Life Sciences]', 'Thalia: Semantic search engine for biomedical abstracts']
#
# Cluster 2(N=27)
# ['Federated machine learning: Concept and applications', 'Machine learning analysis of gene expression data reveals novel diagnostic and prognostic biomarkers and identifies therapeutic targets for soft tissue sarcomas', 'EncoderMap: Dimensionality Reduction and Generation of Molecule Conformations', 'Adaptive Motion Planning Based on Vehicle Characteristics and Regulations for Off-Road UGVs', 'Redundancy principle and the role of extreme statistics in molecular and cellular biology', 'Pattern recognition analysis on long noncoding RNAs: A tool for prediction in plants', 'Audio-Material Reconstruction for Virtualized Reality Using a Probabilistic Damping Model', 'IRIS-EDA: An integrated RNA-seq interpretation system for gene expression data analysis', 'Origin-Destination Flow Maps in Immersive Environments', 'Can atlas-based auto-segmentation ever be perfect? Insights from extreme value theory', 'High-performance liquid alloy patterning of epidermal strain sensors for local fine skin movement monitoring', 'SGaze: A Data-Driven Eye-Head Coordination Model for Realtime Gaze Prediction', 'Progress in context-aware recommender systems - An overview', 'Operations research for sustainability assessment of products: A review', 'Perceptually Based Adaptive Motion Retargeting to Animate Real Objects by Light Projection', 'Pareto-Based Maintenance Decisions for Regional Railways with Uncertain Weld Conditions Using the Hilbert Spectrum of Axle Box Acceleration', 'Smart brushing for parallel coordinates', 'Visual Analysis of Spatia-temporal Relations of Pairwise Attributes in Unsteady Flow', 'GFN2-xTB - An Accurate and Broadly Parametrized Self-Consistent Tight-Binding Quantum Chemical Method with Multipole Electrostatics and Density-Dependent Dispersion Contributions', 'A Switched Systems Approach to Path Following With Intermittent State Feedback', 'Dynamic BIM-augmented UAV safety inspection for water diversion project', 'Ensemble Neural Networks (ENN): A gradient-free stochastic method', 'A stochastic program to evaluate disruption mitigation investments in the supply chain', 'AGRA: AI-augmented geographic routing approach for IoT-based incident-supporting applications', 'Motion Deblurring of Faces', 'Will TCP Work in mmWave 5G Cellular Networks?', 'Non-intrusive Sparse Subspace Learning for Parametrized Problems']
#
# Cluster 3(N=19)
# ['In the shades of the uncanny valley: An experimental study of human–chatbot interaction', 'Automatic virtual impedance adaptation of a knee exoskeleton for personalized walking assistance', 'An Evaluation of Depth and Size Perception on a Spherical Fish Tank Virtual Reality Display', 'Identification of avian flapping motion from non-volant winged dinosaurs based on modal effective mass analysis', 'Multi-goal motion planning using traveling salesman problem in belief space', 'A distributed, plug-n-play algorithm for multi-robot applications with a priori non-computable objective functions', 'FermiSurfer: Fermi-surface viewer providing multiple representation schemes', 'TrackerBots: Autonomous unmanned aerial vehicle for real-time localization and tracking of multiple radio-tagged animals', 'BIM-Tracker: A model-based visual tracking approach for indoor localisation using a 3D building model', 'Robot Learning System Based on Adaptive Neural Control and Dynamic Movement Primitives', 'Real-Time Robotic Manipulation of Cylindrical Objects in Dynamic Scenarios Through Elliptic Shape Primitives', 'Robotic Skill Learning for Precision Assembly with Microscopic Vision and Force Feedback', 'Sensor-based reactive navigation in unknown convex sphere worlds', 'Multi-robot rendezvous based on bearing-aided hierarchical tracking of network topology', 'Automatic Couplings with Mechanical Overload Protection for Modular Robots', 'How instructors frame students’ interactions with educational technologies can enhance or reduce learning with multiple representations', 'Robotic Insertion of Flexible Needle in Deformable Structures Using Inverse Finite-Element Simulation', 'Control of Nonprehensile Planar Rolling Manipulation: A Passivity-Based Approach', 'Modeling interaction structure for robot imitation learning of human social behavior']

# %%
scopus_2019_life.cluster_scopus(target_column="Abstract", train_kmeans=False, pca_components=3)
# Out:
# 	Command set: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`
# 	sql: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`;
# # Total DOIs: 14330	# DOIs w/ videos: 61	Ratio: 0.004
# # Total videos: 79	# Target videos: 77	Ratio: 0.975
# # Total subjects: 46	# subjects w/ videos: 22	Ratio: 0.478
# # Total journals: 133	# journals w/ videos: 36	Ratio: 0.271
# # Total elements in plot: 61
# Cluster 1(N=15)
# ['Assessing binge-watching behaviors: Development and validation of the “Watching TV Series Motives” and “Binge-watching Engagement and Symptoms” questionnaires', 'Smartphones reduce smiles between strangers', 'A manifesto for future generation cloud computing: Research directions for the next decade', 'Social media data and post-disaster recovery', 'The Internet and Facebook Usage on Academic Distraction of College Students', 'Applying learning analytics to students’ interaction in business simulation games. The usefulness of learning analytics to know what students really learn', 'Locomotion in virtual reality for room scale tracked areas', 'Girls’ video gaming behaviour and undergraduate degree selection: A secondary data analysis approach', 'Latent goal models for dynamic strategic interaction', 'Digitization of music: Consumer adoption amidst piracy, unbundling, and rebundling', 'Visual Analysis of Aneurysm Data using Statistical Graphics', 'Ten simple rules towards healthier research labs', 'Deep full-body motion network for a soft wearable motion sensing suit', 'Computational Deglutition: Using Signal- and Image-Processing Methods to Understand Swallowing and Associated Disorders [Life Sciences]', 'Thalia: Semantic search engine for biomedical abstracts']
#
# Cluster 2(N=27)
# ['Federated machine learning: Concept and applications', 'Machine learning analysis of gene expression data reveals novel diagnostic and prognostic biomarkers and identifies therapeutic targets for soft tissue sarcomas', 'EncoderMap: Dimensionality Reduction and Generation of Molecule Conformations', 'Adaptive Motion Planning Based on Vehicle Characteristics and Regulations for Off-Road UGVs', 'Redundancy principle and the role of extreme statistics in molecular and cellular biology', 'Pattern recognition analysis on long noncoding RNAs: A tool for prediction in plants', 'Audio-Material Reconstruction for Virtualized Reality Using a Probabilistic Damping Model', 'IRIS-EDA: An integrated RNA-seq interpretation system for gene expression data analysis', 'Origin-Destination Flow Maps in Immersive Environments', 'Can atlas-based auto-segmentation ever be perfect? Insights from extreme value theory', 'High-performance liquid alloy patterning of epidermal strain sensors for local fine skin movement monitoring', 'SGaze: A Data-Driven Eye-Head Coordination Model for Realtime Gaze Prediction', 'Progress in context-aware recommender systems - An overview', 'Operations research for sustainability assessment of products: A review', 'Perceptually Based Adaptive Motion Retargeting to Animate Real Objects by Light Projection', 'Pareto-Based Maintenance Decisions for Regional Railways with Uncertain Weld Conditions Using the Hilbert Spectrum of Axle Box Acceleration', 'Smart brushing for parallel coordinates', 'Visual Analysis of Spatia-temporal Relations of Pairwise Attributes in Unsteady Flow', 'GFN2-xTB - An Accurate and Broadly Parametrized Self-Consistent Tight-Binding Quantum Chemical Method with Multipole Electrostatics and Density-Dependent Dispersion Contributions', 'A Switched Systems Approach to Path Following With Intermittent State Feedback', 'Dynamic BIM-augmented UAV safety inspection for water diversion project', 'Ensemble Neural Networks (ENN): A gradient-free stochastic method', 'A stochastic program to evaluate disruption mitigation investments in the supply chain', 'AGRA: AI-augmented geographic routing approach for IoT-based incident-supporting applications', 'Motion Deblurring of Faces', 'Will TCP Work in mmWave 5G Cellular Networks?', 'Non-intrusive Sparse Subspace Learning for Parametrized Problems']
#
# Cluster 3(N=19)
# ['In the shades of the uncanny valley: An experimental study of human–chatbot interaction', 'Automatic virtual impedance adaptation of a knee exoskeleton for personalized walking assistance', 'An Evaluation of Depth and Size Perception on a Spherical Fish Tank Virtual Reality Display', 'Identification of avian flapping motion from non-volant winged dinosaurs based on modal effective mass analysis', 'Multi-goal motion planning using traveling salesman problem in belief space', 'A distributed, plug-n-play algorithm for multi-robot applications with a priori non-computable objective functions', 'FermiSurfer: Fermi-surface viewer providing multiple representation schemes', 'TrackerBots: Autonomous unmanned aerial vehicle for real-time localization and tracking of multiple radio-tagged animals', 'BIM-Tracker: A model-based visual tracking approach for indoor localisation using a 3D building model', 'Robot Learning System Based on Adaptive Neural Control and Dynamic Movement Primitives', 'Real-Time Robotic Manipulation of Cylindrical Objects in Dynamic Scenarios Through Elliptic Shape Primitives', 'Robotic Skill Learning for Precision Assembly with Microscopic Vision and Force Feedback', 'Sensor-based reactive navigation in unknown convex sphere worlds', 'Multi-robot rendezvous based on bearing-aided hierarchical tracking of network topology', 'Automatic Couplings with Mechanical Overload Protection for Modular Robots', 'How instructors frame students’ interactions with educational technologies can enhance or reduce learning with multiple representations', 'Robotic Insertion of Flexible Needle in Deformable Structures Using Inverse Finite-Element Simulation', 'Control of Nonprehensile Planar Rolling Manipulation: A Passivity-Based Approach', 'Modeling interaction structure for robot imitation learning of human social behavior']

# %%
scopus_2019_life.desc_clusters(scopus_2019_life.clustered_subjects)
# Out:
# Cluster 1(N=15)
# ['Arts and Humanities (miscellaneous)', 'Arts and Humanities (miscellaneous)', 'General Computer Science', 'Information Systems', 'General Computer Science', 'Arts and Humanities (miscellaneous)', 'Human-Computer Interaction', 'Arts and Humanities (miscellaneous)', 'Cellular and Molecular Neuroscience', 'Information Systems', 'Signal Processing', 'Cellular and Molecular Neuroscience', 'Electrical and Electronic Engineering', 'Signal Processing', 'Biochemistry']
#
# Cluster 2(N=27)
# ['Artificial Intelligence', 'Cellular and Molecular Neuroscience', 'Physical and Theoretical Chemistry', 'Information Systems', 'General Physics and Astronomy', 'Information Systems', 'Signal Processing', 'Cellular and Molecular Neuroscience', 'Signal Processing', 'Software', 'Artificial Intelligence', 'Signal Processing', 'General Computer Science', 'Information Systems and Management', 'Signal Processing', 'Information Systems', 'Signal Processing', 'Signal Processing', 'Physical and Theoretical Chemistry', 'Computer Science Applications', 'General Engineering', 'Cognitive Neuroscience', 'Information Systems and Management', 'Computer Networks and Communications', 'Computer Vision and Pattern Recognition', 'Electrical and Electronic Engineering', 'Applied Mathematics']
#
# Cluster 3(N=19)
# ['Computer Networks and Communications', 'Computer Science Applications', 'Signal Processing', 'Cellular and Molecular Neuroscience', 'Artificial Intelligence', 'Modeling and Simulation', 'Hardware and Architecture', 'Computer Science Applications', 'Computers in Earth Sciences', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Modeling and Simulation', 'Software', 'Electrical and Electronic Engineering', 'General Computer Science', 'Computer Science Applications', 'Computer Science Applications', 'Artificial Intelligence']

# %%
scopus_2019_life.cluster_scopus(target_column="Abstract", num_clusters=5)
# Out:
# 	Command set: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`
# 	sql: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`;
# # Total DOIs: 14330	# DOIs w/ videos: 61	Ratio: 0.004
# # Total videos: 79	# Target videos: 77	Ratio: 0.975
# # Total subjects: 46	# subjects w/ videos: 22	Ratio: 0.478
# # Total journals: 133	# journals w/ videos: 36	Ratio: 0.271
# # Total elements in plot: 61
# Cluster 1(N=2)
# ['A manifesto for future generation cloud computing: Research directions for the next decade', 'Will TCP Work in mmWave 5G Cellular Networks?']
#
# Cluster 2(N=17)
# ['EncoderMap: Dimensionality Reduction and Generation of Molecule Conformations', 'Audio-Material Reconstruction for Virtualized Reality Using a Probabilistic Damping Model', 'Can atlas-based auto-segmentation ever be perfect? Insights from extreme value theory', 'SGaze: A Data-Driven Eye-Head Coordination Model for Realtime Gaze Prediction', 'FermiSurfer: Fermi-surface viewer providing multiple representation schemes', 'Progress in context-aware recommender systems - An overview', 'Perceptually Based Adaptive Motion Retargeting to Animate Real Objects by Light Projection', 'Pareto-Based Maintenance Decisions for Regional Railways with Uncertain Weld Conditions Using the Hilbert Spectrum of Axle Box Acceleration', 'GFN2-xTB - An Accurate and Broadly Parametrized Self-Consistent Tight-Binding Quantum Chemical Method with Multipole Electrostatics and Density-Dependent Dispersion Contributions', 'A Switched Systems Approach to Path Following With Intermittent State Feedback', 'BIM-Tracker: A model-based visual tracking approach for indoor localisation using a 3D building model', 'Dynamic BIM-augmented UAV safety inspection for water diversion project', 'Ensemble Neural Networks (ENN): A gradient-free stochastic method', 'A stochastic program to evaluate disruption mitigation investments in the supply chain', 'AGRA: AI-augmented geographic routing approach for IoT-based incident-supporting applications', 'Motion Deblurring of Faces', 'Non-intrusive Sparse Subspace Learning for Parametrized Problems']
#
# Cluster 3(N=9)
# ['Assessing binge-watching behaviors: Development and validation of the “Watching TV Series Motives” and “Binge-watching Engagement and Symptoms” questionnaires', 'Smartphones reduce smiles between strangers', 'Social media data and post-disaster recovery', 'The Internet and Facebook Usage on Academic Distraction of College Students', 'Applying learning analytics to students’ interaction in business simulation games. The usefulness of learning analytics to know what students really learn', 'Girls’ video gaming behaviour and undergraduate degree selection: A secondary data analysis approach', 'Latent goal models for dynamic strategic interaction', 'Digitization of music: Consumer adoption amidst piracy, unbundling, and rebundling', 'Ten simple rules towards healthier research labs']
#
# Cluster 4(N=18)
# ['Federated machine learning: Concept and applications', 'Machine learning analysis of gene expression data reveals novel diagnostic and prognostic biomarkers and identifies therapeutic targets for soft tissue sarcomas', 'Adaptive Motion Planning Based on Vehicle Characteristics and Regulations for Off-Road UGVs', 'Redundancy principle and the role of extreme statistics in molecular and cellular biology', 'Pattern recognition analysis on long noncoding RNAs: A tool for prediction in plants', 'An Evaluation of Depth and Size Perception on a Spherical Fish Tank Virtual Reality Display', 'Identification of avian flapping motion from non-volant winged dinosaurs based on modal effective mass analysis', 'IRIS-EDA: An integrated RNA-seq interpretation system for gene expression data analysis', 'Origin-Destination Flow Maps in Immersive Environments', 'High-performance liquid alloy patterning of epidermal strain sensors for local fine skin movement monitoring', 'Locomotion in virtual reality for room scale tracked areas', 'Operations research for sustainability assessment of products: A review', 'Smart brushing for parallel coordinates', 'Visual Analysis of Spatia-temporal Relations of Pairwise Attributes in Unsteady Flow', 'Visual Analysis of Aneurysm Data using Statistical Graphics', 'Deep full-body motion network for a soft wearable motion sensing suit', 'Computational Deglutition: Using Signal- and Image-Processing Methods to Understand Swallowing and Associated Disorders [Life Sciences]', 'Thalia: Semantic search engine for biomedical abstracts']
#
# Cluster 5(N=15)
# ['In the shades of the uncanny valley: An experimental study of human–chatbot interaction', 'Automatic virtual impedance adaptation of a knee exoskeleton for personalized walking assistance', 'Multi-goal motion planning using traveling salesman problem in belief space', 'A distributed, plug-n-play algorithm for multi-robot applications with a priori non-computable objective functions', 'TrackerBots: Autonomous unmanned aerial vehicle for real-time localization and tracking of multiple radio-tagged animals', 'Robot Learning System Based on Adaptive Neural Control and Dynamic Movement Primitives', 'Real-Time Robotic Manipulation of Cylindrical Objects in Dynamic Scenarios Through Elliptic Shape Primitives', 'Robotic Skill Learning for Precision Assembly with Microscopic Vision and Force Feedback', 'Sensor-based reactive navigation in unknown convex sphere worlds', 'Multi-robot rendezvous based on bearing-aided hierarchical tracking of network topology', 'Automatic Couplings with Mechanical Overload Protection for Modular Robots', 'How instructors frame students’ interactions with educational technologies can enhance or reduce learning with multiple representations', 'Robotic Insertion of Flexible Needle in Deformable Structures Using Inverse Finite-Element Simulation', 'Control of Nonprehensile Planar Rolling Manipulation: A Passivity-Based Approach', 'Modeling interaction structure for robot imitation learning of human social behavior']

# %% [markdown]
# c1?: c2:Robotics c3:? c4:ML c5:?

# %%
scopus_2019_life.cluster_scopus(target_column="Abstract", train_kmeans=False, pca_components=3)
# Out:
# 	Command set: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`
# 	sql: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`;
# # Total DOIs: 14330	# DOIs w/ videos: 61	Ratio: 0.004
# # Total videos: 79	# Target videos: 77	Ratio: 0.975
# # Total subjects: 46	# subjects w/ videos: 22	Ratio: 0.478
# # Total journals: 133	# journals w/ videos: 36	Ratio: 0.271
# # Total elements in plot: 61
# Cluster 1(N=2)
# ['A manifesto for future generation cloud computing: Research directions for the next decade', 'Will TCP Work in mmWave 5G Cellular Networks?']
#
# Cluster 2(N=17)
# ['EncoderMap: Dimensionality Reduction and Generation of Molecule Conformations', 'Audio-Material Reconstruction for Virtualized Reality Using a Probabilistic Damping Model', 'Can atlas-based auto-segmentation ever be perfect? Insights from extreme value theory', 'SGaze: A Data-Driven Eye-Head Coordination Model for Realtime Gaze Prediction', 'FermiSurfer: Fermi-surface viewer providing multiple representation schemes', 'Progress in context-aware recommender systems - An overview', 'Perceptually Based Adaptive Motion Retargeting to Animate Real Objects by Light Projection', 'Pareto-Based Maintenance Decisions for Regional Railways with Uncertain Weld Conditions Using the Hilbert Spectrum of Axle Box Acceleration', 'GFN2-xTB - An Accurate and Broadly Parametrized Self-Consistent Tight-Binding Quantum Chemical Method with Multipole Electrostatics and Density-Dependent Dispersion Contributions', 'A Switched Systems Approach to Path Following With Intermittent State Feedback', 'BIM-Tracker: A model-based visual tracking approach for indoor localisation using a 3D building model', 'Dynamic BIM-augmented UAV safety inspection for water diversion project', 'Ensemble Neural Networks (ENN): A gradient-free stochastic method', 'A stochastic program to evaluate disruption mitigation investments in the supply chain', 'AGRA: AI-augmented geographic routing approach for IoT-based incident-supporting applications', 'Motion Deblurring of Faces', 'Non-intrusive Sparse Subspace Learning for Parametrized Problems']
#
# Cluster 3(N=9)
# ['Assessing binge-watching behaviors: Development and validation of the “Watching TV Series Motives” and “Binge-watching Engagement and Symptoms” questionnaires', 'Smartphones reduce smiles between strangers', 'Social media data and post-disaster recovery', 'The Internet and Facebook Usage on Academic Distraction of College Students', 'Applying learning analytics to students’ interaction in business simulation games. The usefulness of learning analytics to know what students really learn', 'Girls’ video gaming behaviour and undergraduate degree selection: A secondary data analysis approach', 'Latent goal models for dynamic strategic interaction', 'Digitization of music: Consumer adoption amidst piracy, unbundling, and rebundling', 'Ten simple rules towards healthier research labs']
#
# Cluster 4(N=18)
# ['Federated machine learning: Concept and applications', 'Machine learning analysis of gene expression data reveals novel diagnostic and prognostic biomarkers and identifies therapeutic targets for soft tissue sarcomas', 'Adaptive Motion Planning Based on Vehicle Characteristics and Regulations for Off-Road UGVs', 'Redundancy principle and the role of extreme statistics in molecular and cellular biology', 'Pattern recognition analysis on long noncoding RNAs: A tool for prediction in plants', 'An Evaluation of Depth and Size Perception on a Spherical Fish Tank Virtual Reality Display', 'Identification of avian flapping motion from non-volant winged dinosaurs based on modal effective mass analysis', 'IRIS-EDA: An integrated RNA-seq interpretation system for gene expression data analysis', 'Origin-Destination Flow Maps in Immersive Environments', 'High-performance liquid alloy patterning of epidermal strain sensors for local fine skin movement monitoring', 'Locomotion in virtual reality for room scale tracked areas', 'Operations research for sustainability assessment of products: A review', 'Smart brushing for parallel coordinates', 'Visual Analysis of Spatia-temporal Relations of Pairwise Attributes in Unsteady Flow', 'Visual Analysis of Aneurysm Data using Statistical Graphics', 'Deep full-body motion network for a soft wearable motion sensing suit', 'Computational Deglutition: Using Signal- and Image-Processing Methods to Understand Swallowing and Associated Disorders [Life Sciences]', 'Thalia: Semantic search engine for biomedical abstracts']
#
# Cluster 5(N=15)
# ['In the shades of the uncanny valley: An experimental study of human–chatbot interaction', 'Automatic virtual impedance adaptation of a knee exoskeleton for personalized walking assistance', 'Multi-goal motion planning using traveling salesman problem in belief space', 'A distributed, plug-n-play algorithm for multi-robot applications with a priori non-computable objective functions', 'TrackerBots: Autonomous unmanned aerial vehicle for real-time localization and tracking of multiple radio-tagged animals', 'Robot Learning System Based on Adaptive Neural Control and Dynamic Movement Primitives', 'Real-Time Robotic Manipulation of Cylindrical Objects in Dynamic Scenarios Through Elliptic Shape Primitives', 'Robotic Skill Learning for Precision Assembly with Microscopic Vision and Force Feedback', 'Sensor-based reactive navigation in unknown convex sphere worlds', 'Multi-robot rendezvous based on bearing-aided hierarchical tracking of network topology', 'Automatic Couplings with Mechanical Overload Protection for Modular Robots', 'How instructors frame students’ interactions with educational technologies can enhance or reduce learning with multiple representations', 'Robotic Insertion of Flexible Needle in Deformable Structures Using Inverse Finite-Element Simulation', 'Control of Nonprehensile Planar Rolling Manipulation: A Passivity-Based Approach', 'Modeling interaction structure for robot imitation learning of human social behavior']

# %%
scopus_2019_life.desc_clusters(scopus_2019_life.clustered_subjects)
# Out:
# Cluster 1(N=2)
# ['General Computer Science', 'Electrical and Electronic Engineering']
#
# Cluster 2(N=17)
# ['Physical and Theoretical Chemistry', 'Signal Processing', 'Software', 'Signal Processing', 'Hardware and Architecture', 'General Computer Science', 'Signal Processing', 'Information Systems', 'Physical and Theoretical Chemistry', 'Computer Science Applications', 'Computers in Earth Sciences', 'General Engineering', 'Cognitive Neuroscience', 'Information Systems and Management', 'Computer Networks and Communications', 'Computer Vision and Pattern Recognition', 'Applied Mathematics']
#
# Cluster 3(N=9)
# ['Arts and Humanities (miscellaneous)', 'Arts and Humanities (miscellaneous)', 'Information Systems', 'General Computer Science', 'Arts and Humanities (miscellaneous)', 'Arts and Humanities (miscellaneous)', 'Cellular and Molecular Neuroscience', 'Information Systems', 'Cellular and Molecular Neuroscience']
#
# Cluster 4(N=18)
# ['Artificial Intelligence', 'Cellular and Molecular Neuroscience', 'Information Systems', 'General Physics and Astronomy', 'Information Systems', 'Signal Processing', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Signal Processing', 'Artificial Intelligence', 'Human-Computer Interaction', 'Information Systems and Management', 'Signal Processing', 'Signal Processing', 'Signal Processing', 'Electrical and Electronic Engineering', 'Signal Processing', 'Biochemistry']
#
# Cluster 5(N=15)
# ['Computer Networks and Communications', 'Computer Science Applications', 'Artificial Intelligence', 'Modeling and Simulation', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Modeling and Simulation', 'Software', 'Electrical and Electronic Engineering', 'General Computer Science', 'Computer Science Applications', 'Computer Science Applications', 'Artificial Intelligence']

# %%
scopus_2019_life.cluster_scopus(num_clusters=10)
# Out:
# 	Command set: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`
# 	sql: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`;
# # Total DOIs: 14330	# DOIs w/ videos: 61	Ratio: 0.004
# # Total videos: 79	# Target videos: 77	Ratio: 0.975
# # Total subjects: 46	# subjects w/ videos: 22	Ratio: 0.478
# # Total journals: 133	# journals w/ videos: 36	Ratio: 0.271
# # Total elements in plot: 61
# Cluster 1(N=8)
# ['An Evaluation of Depth and Size Perception on a Spherical Fish Tank Virtual Reality Display', 'A distributed, plug-n-play algorithm for multi-robot applications with a priori non-computable objective functions', 'TrackerBots: Autonomous unmanned aerial vehicle for real-time localization and tracking of multiple radio-tagged animals', 'BIM-Tracker: A model-based visual tracking approach for indoor localisation using a 3D building model', 'Real-Time Robotic Manipulation of Cylindrical Objects in Dynamic Scenarios Through Elliptic Shape Primitives', 'Sensor-based reactive navigation in unknown convex sphere worlds', 'Multi-robot rendezvous based on bearing-aided hierarchical tracking of network topology', 'Automatic Couplings with Mechanical Overload Protection for Modular Robots']
#
# Cluster 2(N=1)
# ['Girls’ video gaming behaviour and undergraduate degree selection: A secondary data analysis approach']
#
# Cluster 3(N=3)
# ['Federated machine learning: Concept and applications', 'Adaptive Motion Planning Based on Vehicle Characteristics and Regulations for Off-Road UGVs', 'A Switched Systems Approach to Path Following With Intermittent State Feedback']
#
# Cluster 4(N=7)
# ['Assessing binge-watching behaviors: Development and validation of the “Watching TV Series Motives” and “Binge-watching Engagement and Symptoms” questionnaires', 'Smartphones reduce smiles between strangers', 'A manifesto for future generation cloud computing: Research directions for the next decade', 'The Internet and Facebook Usage on Academic Distraction of College Students', 'Applying learning analytics to students’ interaction in business simulation games. The usefulness of learning analytics to know what students really learn', 'Latent goal models for dynamic strategic interaction', 'Digitization of music: Consumer adoption amidst piracy, unbundling, and rebundling']
#
# Cluster 5(N=3)
# ['Redundancy principle and the role of extreme statistics in molecular and cellular biology', 'A stochastic program to evaluate disruption mitigation investments in the supply chain', 'Motion Deblurring of Faces']
#
# Cluster 6(N=2)
# ['Can atlas-based auto-segmentation ever be perfect? Insights from extreme value theory', 'Pareto-Based Maintenance Decisions for Regional Railways with Uncertain Weld Conditions Using the Hilbert Spectrum of Axle Box Acceleration']
#
# Cluster 7(N=10)
# ['Machine learning analysis of gene expression data reveals novel diagnostic and prognostic biomarkers and identifies therapeutic targets for soft tissue sarcomas', 'Identification of avian flapping motion from non-volant winged dinosaurs based on modal effective mass analysis', 'Locomotion in virtual reality for room scale tracked areas', 'Smart brushing for parallel coordinates', 'Visual Analysis of Aneurysm Data using Statistical Graphics', 'Ten simple rules towards healthier research labs', 'Deep full-body motion network for a soft wearable motion sensing suit', 'Computational Deglutition: Using Signal- and Image-Processing Methods to Understand Swallowing and Associated Disorders [Life Sciences]', 'Thalia: Semantic search engine for biomedical abstracts', 'Robotic Insertion of Flexible Needle in Deformable Structures Using Inverse Finite-Element Simulation']
#
# Cluster 8(N=10)
# ['EncoderMap: Dimensionality Reduction and Generation of Molecule Conformations', 'Pattern recognition analysis on long noncoding RNAs: A tool for prediction in plants', 'IRIS-EDA: An integrated RNA-seq interpretation system for gene expression data analysis', 'Social media data and post-disaster recovery', 'High-performance liquid alloy patterning of epidermal strain sensors for local fine skin movement monitoring', 'Operations research for sustainability assessment of products: A review', 'Visual Analysis of Spatia-temporal Relations of Pairwise Attributes in Unsteady Flow', 'Dynamic BIM-augmented UAV safety inspection for water diversion project', 'AGRA: AI-augmented geographic routing approach for IoT-based incident-supporting applications', 'Will TCP Work in mmWave 5G Cellular Networks?']
#
# Cluster 9(N=8)
# ['Audio-Material Reconstruction for Virtualized Reality Using a Probabilistic Damping Model', 'Origin-Destination Flow Maps in Immersive Environments', 'SGaze: A Data-Driven Eye-Head Coordination Model for Realtime Gaze Prediction', 'FermiSurfer: Fermi-surface viewer providing multiple representation schemes', 'Perceptually Based Adaptive Motion Retargeting to Animate Real Objects by Light Projection', 'GFN2-xTB - An Accurate and Broadly Parametrized Self-Consistent Tight-Binding Quantum Chemical Method with Multipole Electrostatics and Density-Dependent Dispersion Contributions', 'Ensemble Neural Networks (ENN): A gradient-free stochastic method', 'Non-intrusive Sparse Subspace Learning for Parametrized Problems']
#
# Cluster 10(N=9)
# ['In the shades of the uncanny valley: An experimental study of human–chatbot interaction', 'Automatic virtual impedance adaptation of a knee exoskeleton for personalized walking assistance', 'Multi-goal motion planning using traveling salesman problem in belief space', 'Progress in context-aware recommender systems - An overview', 'Robot Learning System Based on Adaptive Neural Control and Dynamic Movement Primitives', 'Robotic Skill Learning for Precision Assembly with Microscopic Vision and Force Feedback', 'How instructors frame students’ interactions with educational technologies can enhance or reduce learning with multiple representations', 'Control of Nonprehensile Planar Rolling Manipulation: A Passivity-Based Approach', 'Modeling interaction structure for robot imitation learning of human social behavior']

# %%
scopus_2019_life.desc_clusters(scopus_2019_life.clustered_subjects)
# Out:
# Cluster 1(N=8)
# ['Signal Processing', 'Modeling and Simulation', 'Computer Science Applications', 'Computers in Earth Sciences', 'Computer Science Applications', 'Modeling and Simulation', 'Software', 'Electrical and Electronic Engineering']
#
# Cluster 2(N=1)
# ['Arts and Humanities (miscellaneous)']
#
# Cluster 3(N=3)
# ['Artificial Intelligence', 'Information Systems', 'Computer Science Applications']
#
# Cluster 4(N=7)
# ['Arts and Humanities (miscellaneous)', 'Arts and Humanities (miscellaneous)', 'General Computer Science', 'General Computer Science', 'Arts and Humanities (miscellaneous)', 'Cellular and Molecular Neuroscience', 'Information Systems']
#
# Cluster 5(N=3)
# ['General Physics and Astronomy', 'Information Systems and Management', 'Computer Vision and Pattern Recognition']
#
# Cluster 6(N=2)
# ['Software', 'Information Systems']
#
# Cluster 7(N=10)
# ['Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Human-Computer Interaction', 'Signal Processing', 'Signal Processing', 'Cellular and Molecular Neuroscience', 'Electrical and Electronic Engineering', 'Signal Processing', 'Biochemistry', 'Computer Science Applications']
#
# Cluster 8(N=10)
# ['Physical and Theoretical Chemistry', 'Information Systems', 'Cellular and Molecular Neuroscience', 'Information Systems', 'Artificial Intelligence', 'Information Systems and Management', 'Signal Processing', 'General Engineering', 'Computer Networks and Communications', 'Electrical and Electronic Engineering']
#
# Cluster 9(N=8)
# ['Signal Processing', 'Signal Processing', 'Signal Processing', 'Hardware and Architecture', 'Signal Processing', 'Physical and Theoretical Chemistry', 'Cognitive Neuroscience', 'Applied Mathematics']
#
# Cluster 10(N=9)
# ['Computer Networks and Communications', 'Computer Science Applications', 'Artificial Intelligence', 'General Computer Science', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'General Computer Science', 'Computer Science Applications', 'Artificial Intelligence']

# %% [markdown]
# 전체를 클러스터링

# %%
scopus_2019_life.cluster_scopus(num_clusters=100, videos_only=False)
# Out:
# [+]Assigning new embedder instance.
# 	Command set: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`
# 	sql: SELECT `idx`, `videoId`, `idx_paper`, `publishedAt` FROM `scopus_videos_2019_comp`;
# # Total DOIs: 14330	# DOIs w/ videos: 61	Ratio: 0.004
# # Total videos: 79	# Target videos: 77	Ratio: 0.975
# # Total subjects: 46	# subjects w/ videos: 22	Ratio: 0.478
# # Total journals: 133	# journals w/ videos: 36	Ratio: 0.271
# # Total elements in plot: 14091
# Cluster 1(N=110)
# ['Incorporating Wind Energy in Power System Restoration Planning', 'Coordinated Optimal Network Reconfiguration and Voltage Regulator/DER Control for Unbalanced Distribution Systems', 'Automotive Traction Inverters: Current Status and Future Trends', 'Slope-Weighted Energy-Based Rapid Control Analysis for Hybrid Electric Vehicles', 'An adaptive fuzzy logic control strategy for performance enhancement of a grid-connected PMSG-Based wind turbine', 'LSTM-EFG for wind power forecasting based on sequential correlation features', 'Enhanced goal attainment method for solving multi-objective security-constrained optimal power flow considering dynamic thermal rating of lines', 'An improved defender-attacker-defender model for transmission line defense considering offensive resource uncertainties', 'Information exchange based clustered differential evolution for constrained generation-transmission expansion planning', 'Adaptive Dynamic Simulations for Distribution Systems Using Multistate Load Models', 'Study on the acoustic emission effect of plasma plume in pulsed laser welding', 'A Novel Composite Nonlinear Controller for Stabilization of Constant Power Load in DC Microgrid', 'DROpS: A demand response optimization scheme in SDN-enabled smart energy ecosystem', 'Investigation of power quality disturbances by using 2D discrete orthonormal S-transform, machine learning and multi-objective evolutionary algorithms', 'Electrochemical direct-writing machining of micro-channel array', 'Explosive synchronization transition in a ring of coupled oscillators', 'Hybrid voltage control in distribution networks under limited communication rates', 'Engine start-up optimal control for a compound power-split hybrid powertrain', 'Ensemble-Based Algorithm for Synchrophasor Data Anomaly Detection', 'Design of a Novel Piezoelectric Energy Harvester Based on Integrated Multistage Force Amplification Frame', 'A multichannel low-power wide-area network with high-accuracy synchronization ability for machine vibration monitoring', 'Noise insensitive optimal harmonic estimator design with lightning search algorithm', 'A strengthened mixed-integer linear programming formulation for combined-cycle units', 'A New Grouping Protocol for Smart Grids', 'Energy proportional neural network inference with adaptive voltage and frequency scaling', 'Optimal Number of Electric Vehicles for Existing Networks Considering Economic and Emission Dispatch', 'On the emerging class of non-isolated modular multilevel DC-DC converters for DC and hybrid AC-DC systems', 'A Novel Thermal Energy Storage System in Smart Building Based on Phase Change Material', 'A unified acceptance test framework for power plant gas turbine control systems', 'Operational Reliability Assessment for Gas-Electric Integrated Distribution Feeders', 'A Big Data platform for smart meter data analytics', 'Characterization and modeling of power line corridor elements from LiDAR point clouds', 'Global Trends in High-Power On-Board Chargers for Electric Vehicles', 'Power management method for large ports with multi-agent systems', 'Distributed multienergy coordination of multimicrogrids with biogas-solar-wind renewables', 'Walking propulsion generation in double stance by powered exoskeleton for paraplegics', 'A Network-Topology-Based Approach for the Load-Flow Solution of AC-DC Distribution System with Distributed Generations', 'Increased power output of an electromagnetic vibration energy harvester through anti-phase resonance', 'A Hierarchical Self-Adaptive Data-Analytics Method for Real-Time Power System Short-Term Voltage Stability Assessment', 'Smart Loads for Improving the Fault-Ride-Through Capability of Fixed-Speed Wind Generators in Microgrids', 'A New Time-Decoupled Framework for PEVs Charging and Scheduling in Industrial Microgrids', 'Analysis of Vth Variations in IGBTs under thermal stress for improved condition monitoring in automotive power conversion systems', 'A Unified Frequency-Domain Model for Au ...
#
# Cluster 2(N=170)
# ['Interactive obstruction-free lensing for volumetric data visualization', 'Which has better visual quality: The clear blue sky or a blurry animal?', 'Detecting unfair recommendations in trust-based pervasive environments', 'Show and Tell in the Loop: Cross-Modal Circular Correlation Learning', 'Embedded feature selection accounting for unknown data heterogeneity', 'Building user profiles based on sequences for content and collaborative filtering', 'Human representation of multimodal distributions as clusters of samples', 'Unsupervised Learning of Human Pose Distance Metric via Sparsity Locality Preserving Projections', 'Repeated discrete choices in geographical agent based models with an application to fisheries', 'Semi-supervised and active learning through Manifold Reciprocal kNN Graph for image retrieval', 'Asynchronous Saddle Point Algorithm for Stochastic Optimization in Heterogeneous Networks', 'Schema-agnostic progressive entity resolution', 'From composites to factors: Bridging the gap between PLS and covariance-based structural equation modelling', 'Modified failure mode and effects analysis under uncertainty: A rough cloud theory-based approach', 'Making the Best of a Bad Situation: A Multiscale Approach to Free Energy Calculation', 'Exploiting forced alignment of time-reversed data for improving HMM-based handwriting segmentation', 'Learning principal orientations and residual descriptor for action recognition', 'Hybrid Hierarchical Reinforcement Learning for online guidance and navigation with partial observability', 'Feature extraction methods for palmprint recognition: A survey and evaluation', 'A collaborative service group-based fuzzy QoS-aware manufacturing service composition using an extended flower pollination algorithm', 'Joint analysis of individual-level and summary-level GWAS data by leveraging pleiotropy', 'A new stochastic simulation algorithm for image-based classification: Feature-space indicator simulation', 'Multi-attribute decision making methods based on reference ideal theory with probabilistic hesitant information', 'Structural regularization in quadratic logistic regression model', 'An Adversarial Neuro-Tensorial Approach for Learning Disentangled Representations', 'The effect of answer validation on the performance of Question-Answering systems', 'An association-based evolutionary ensemble method of variable selection', 'A Classification-Based Surrogate-Assisted Evolutionary Algorithm for Expensive Many-Objective Optimization', 'Multiple criteria risk averse model for multi-product newsvendor problem using conditional value at risk constraints', 'Integrating TOPSIS with interval-valued intuitionistic fuzzy cognitive maps for effective group decision making', 'Improving IoT data quality in mobile crowd sensing: A cross validation approach', 'Enabling Spatio-Temporal Search in Open Data', 'SLIDE - A web-based tool for interactive visualization of large-scale - Omics data', 'A Probabilistic Approach to Cross-Region Matching-Based Image Retrieval', 'Bayes-optimal estimation of overlap between populations of fixed size', 'Negative sequence analysis: A review', 'A General Framework for Auto-Weighted Feature Selection via Global Redundancy Minimization', 'Chain based sampling for monotonic imbalanced classification', 'Empirical investigation of active learning strategies', 'Class imbalance learning using UnderBagging based kernelized extreme learning machine', 'Crossing generative adversarial networks for cross-view person re-identification', 'Semantically Modeling of Object and Context for Categorization', 'Squirrel-cage local binary pattern and its application in video anomaly detection', 'An analysis of p-median location problem: Effects of backup service level and demand assignment policy', 'Blind image quality assessment based on joint log-contrast statistics', 'Face Alignment in Full Pose Range: A 3D Total Solution', 'Robust genetic interaction analysis', 'Addressing the user cold start with ...
#
# Cluster 3(N=66)
# ['Underwater video mosaicing using topology and superpixel-based pairwise stitching', 'Reanalysis of the PacIOOS Hawaiian Island ocean forecast system, an implementation of the regional ocean modeling system v3.6', 'An improved algorithm for estimating the Secchi disk depth from remote sensing data based on the new underwater visibility theory', 'Front delineation and tracking with multiple underwater vehicles', 'Towards highly accurate coral texture images classification using deep convolutional neural networks and data augmentation', 'New exact methods for the time-invariant berth allocation and quay crane assignment problem', 'Understanding narwhal diving behaviour using hidden Markov models with dependent state distributions and long range dependence', 'A Compact Wideband Slot-Loop Directional Antenna for Marine Communication Applications', 'A matrix completion-based multiview learning method for imputing missing values in buoy monitoring data', 'Topology control for energy-efficient localization in mobile underwater sensor networks using stackelberg game', 'A dynamic-shape-prior guided snake model with application in visually tracking dense cell populations', 'An Architecture for Using Autonomous Underwater Vehicles in Wireless Sensor Networks for Underwater Pipeline Monitoring', 'A hyper-heuristic for improving the initial population of whale optimization algorithm', 'Packet Size Optimization for Lifetime Maximization in Underwater Acoustic Sensor Networks', 'Joint localization and tracking design for AUV with asynchronous clocks and state disturbances', 'Shared autonomy for low-cost underwater vehicles', 'An Evaluation of Depth and Size Perception on a Spherical Fish Tank Virtual Reality Display', 'An auv location prediction-based data collection scheme for underwater wireless sensor networks', 'CONet: A Cognitive Ocean Network', 'Sender-Receiver Role-Based Energy-Aware Scheduling for Internet of Underwater Things', 'A Hybrid IMM Based INS/DVL Integration Solution for Underwater Vehicles', 'A dual band algorithm for shallow water depth retrieval from high spatial resolution imagery with no ground truth', 'Distance-vector-based opportunistic routing for underwater acoustic sensor networks', 'Optimizing source and receiver placement in multistatic sonar networks to monitor fixed targets', 'MARLIN-Q: Multi-modal communications for reliable and low-latency underwater data delivery', 'SMCε, a coastal modeling system for assessing beach processes and coastal interventions: Application to the Brazilian coast', 'Using Wearable Sensors to Capture Posture of the Human Lumbar Spine in Competitive Swimming', 'Automatic Identification System-Based Approach for Assessing the Near-Miss Collision Risk Dynamics of Ships in Ports', 'In-water visual ship hull inspection using a hover-capable underwater vehicle with stereo vision', 'Online motion planning for unexplored underwater environments using autonomous underwater vehicles', 'Machine learning applications in detecting rip channels from images', 'SALMON: Scalable Ab-initio Light–Matter simulator for Optics and Nanoscience', 'Stochastic modeling of depth based routing in underwater sensor networks', 'SKA-PS: Secure key agreement protocol using physiological signals', 'A node depth adjustment method with computation-efficiency based on performance bound for range-only target tracking in UWSNs', 'Robust Ocean Acoustic Localization With Sparse Bayesian Learning', 'Received signal strength based localization in inhomogeneous underwater medium', 'Control and Optimization of a Bionic Robotic Fish Through a Combination of CPG model and PSO', 'Optical-acoustic hybrid network toward real-time video streaming for mobile underwater sensors', 'P-AUV: Position aware routing and medium access for ad hoc AUV networks', 'Velocity free leader-follower formation control for autonomous underwater vehicles with line-of-sight range and angle constraints', 'Towards a gliding robotic dolphin: Design, modeli ...
#
# Cluster 4(N=246)
# ['GLRT detector based on knowledge aided covariance estimation in compound Gaussian environment', 'Parameter estimation of Hammerstein–Wiener nonlinear system with noise using special test signals', 'Time series irreversibility analysis using Jensen–Shannon divergence calculated by permutation pattern', 'Blind separation of temporally correlated noncircular sources using complex matrix joint diagonalization', 'Robust Secure Beamforming for Multibeam Satellite Communication Systems', 'Embedded Pilot-Aided Channel Estimation for OTFS in Delay-Doppler Channels', 'On the Diversity of Uncoded OTFS Modulation in Doubly-Dispersive Channels', 'Symmetric-Strong-Tracking-Extended-Kalman-Filter-Based Sensorless Control of Induction Motor Drives for Modeling Error Reduction', 'Novel secured scheme for blind audio/speech norm-space watermarking by Arnold algorithm', 'Novel Results for the Multivariate Ricean Distribution with Non-Identical Parameters', 'Nonlinear thermoacoustic imaging based on temperature-dependent thermoelastic response', 'Robust Energy Calibration Technique for Photon Counting Spectral Detectors', 'On the Use of the Z Transform of LTI Systems for the Synthesis of Steered Beams and Nulls in the Radiation Pattern of Leaky-Wave Antenna Arrays', 'Scaled accuracy based power allocation for multi-target tracking with colocated MIMO radars', 'Application of improved least-square generative adversarial networks for rail crack detection by AE technique', 'Recovery of non-stationary free field with double-layer pressure measurements', 'Two robust approaches to multicomponent signal reconstruction from STFT ridges', 'Opportunistic Outdated Relays Under Even-Degree-of-Freedom Generalized-Rician Fading', 'Development of a novel knock characteristic detection method for gasoline engines based on wavelet-denoising and EMD decomposition', 'A non-linear material interpolation for design of metallic nano-particles using topology optimization', 'Generalized Finite-Difference Time-Domain method with absorbing boundary conditions for solving the nonlinear Schrödinger equation on a GPU', 'Iterative marginal maximum likelihood DOD and DOA estimation for MIMO radar in the presence of SIRP clutter', 'Wavelet transform based on Meyer algorithm for image edge and blocking artifact reduction', 'Numerical antiresonance continuation of structural systems', 'Error analysis of receive diversity noncoherent PLC system in impulsive noise environment', 'A narrowband active noise control system with a frequency estimation algorithm based on parallel adaptive notch filter', 'Resolving ultrasound contrast microbubbles using minimum variance beamforming', 'On the Two-User MISO Interference Channel with Single-User Decoding: Impact of Imperfect CSIT and Channel Dimension Reduction', 'Robust adaptive beam forming against random calibration error via interference-plus-noise covariance matrix reconstruction', 'An approach based on expectation-maximization algorithm for parameter estimation of Lamb wave signals', 'Performance analysis of LMS filters with non-Gaussian cyclostationary signals', 'Toeplitz covariance matrix of colocated MIMO radar waveforms for SINR maximization', 'Optimal Dual-VENC Unwrapping in Phase-Contrast MRI', 'FADE: Fast and Asymptotically Efficient Distributed Estimator for Dynamic Networks', 'Multi-level context-adaptive correlation tracking', 'Linear Precoding with Low-Resolution DACs for Massive MU-MIMO-OFDM Downlink', 'A novel variational model for noise robust document image binarization', 'State-space adaptive nonlinear self-interference cancellation for full-duplex communication', 'Unsupervised EEG feature extraction based on echo state network', 'Real-time microwave imaging of unknown anomalies via scattering matrix', 'Factorized discriminative conditional variational auto-encoder for radar HRRP target recognition', 'An approximate message passing framework for side information', 'Dynamics and energy generation of a hybrid energy har ...
#
# Cluster 5(N=119)
# ['Examination of smartphone dependence: Functionally and existentially dependent behavior on the smartphone', 'CloneSpot: Fast detection of Android repackages', 'Hadoop MapReduce for Mobile Clouds', 'Mobile banking use: A comparative study with Brazilian and U.S. participants', 'Selfish Decentralized Computation Offloading for Mobile Cloud Computing in Dense Wireless Networks', 'A computation offloading method over big data for IoT-enabled cloud-edge computing', 'Toward hardware-rooted smartphone authentication', 'Encryption-free framework of privacy-preserving image recognition for photo-based information services', 'Sustainable offloading in mobile cloud computing: Algorithmic design and implementation', 'Multi-Dimensional QoS Prediction for Service Recommendations', 'UStash: A novel mobile content delivery system for improving user QoE in public transport', 'Instantaneous vehicle fuel consumption estimation using smartphones and recurrent neural networks', 'Low latency radio access in 3GPP local area data networks for V2X: Stochastic optimization and learning', 'An adaptive and configurable protection framework against android privilege escalation threats', 'Selective mobile cloud offloading to augment multi-persona performance and viability', 'PPTDS: A privacy-preserving truth discovery scheme in crowd sensing systems', 'On data sovereignty in cloud-based computation offloading for smart cities applications', 'A Game Theory Based Efficient Computation Offloading in an UAV Network', 'A Stackelberg Game Approach Toward Socially-Aware Incentive Mechanisms for Mobile Crowdsensing', 'Examining the role of trust and quality dimensions in the actual usage of mobile banking services: An empirical investigation', 'Smartphones reduce smiles between strangers', 'Click sequence prediction in android mobile applications', 'SIGMM: A Novel Machine Learning Algorithm for Spammer Identification in Industrial Mobile Cloud Computing', 'A Novel Ensemble ELM for Human Activity Recognition Using Smartphone Sensors', 'A mobile malware detection method using behavior features in network traffic', 'Dynamic computation offloading for mobile cloud computing: A stochastic game-theoretic approach', 'Deepcachnet: A proactive caching framework based on deep learning in cellular networks', 'Dynamic Pricing for Privacy-Preserving Mobile Crowdsensing: A Reinforcement Learning Approach', 'Using socio-spatial context in mobile cloud process offloading for energy conservation in wireless devices', 'TeMA: A Tensorial Memetic Algorithm for Many-Objective Parallel Disassembly Sequence Planning in Product Refurbishment', 'Task-bundling-based incentive for location-dependent mobile crowdsourcing', 'Nature Inspired Power Optimization in smartphones', 'Combining Automated GUI Exploration of Android apps with Capture and Replay through Machine Learning', 'Mobility-assisted offloading in centrally-coordinated cellular networks', 'Testing the novelty effect of an m-learning tool on internalization and achievement: A Self-Determination Theory approach', 'Mobile Computation Offloading for Application Throughput Fairness and Energy Efficiency', 'Seamless Resource Sharing in Wearable Networks by Application Function Virtualization', 'Recognition of surrounding environment from electric wheelchair videos based on modified YOLOv2', 'On the impact of code smells on the energy consumption of mobile applications', 'Reconstructing what you said: Text inference using smartphone motion', 'Consumer use of mobile banking (M-Banking) in Saudi Arabia: Towards an integrated model', 'Enhancing mobile data services performance via online reviews', 'Impertinent mobiles - Effects of politeness and impoliteness in human-smartphone interaction', 'Sensor analytics for interpretation of EKG signals', 'Using Data Augmentation in Continuous Authentication on Smartphones', 'A nomological network of customers’ privacy perceptions: linking artifact design to shopping efficiency', 'Facilitating prof ...
#
# Cluster 6(N=178)
# ['Debonding detection in CFRP-retrofitted reinforced concrete structures using nonlinear Rayleigh wave', 'Topology optimization for brittle fracture resistance', 'A quadrilateral G1-conforming finite element for the Kirchhoff plate model', 'Random field simulation over curved surfaces: Applications to computational structural mechanics', 'A uniform characterization of augmented shapes', 'Measuring stem diameters with TLS in boreal forests by complementary fitting procedure', 'Theoretical analysis of multi-stable energy harvesters with high-order stiffness terms', 'Analysis of landslides employing a space–time single-phase level-set method', 'Skeleton-stabilized immersogeometric analysis for incompressible viscous flow problems', 'Geometrically non-linear analysis of FG-CNTRC shell structures with surface-bonded piezoelectric layers', 'Geometrically Exact Finite Element Formulations for Slender Beams: Kirchhoff–Love Theory Versus Simo–Reissner Theory', 'Automated homogenization-based fracture analysis: Effects of SVE size and boundary condition', 'A novel DEM approach for modeling brittle elastic media based on distinct lattice spring model', 'NURBS-based formulation for nonlinear electro-gradient elasticity in semiconductors', 'Devito (v3.1.0): An embedded domain-specific language for finite differences and geophysical exploration', 'Torsional instability and sensitivity analysis in a suspension bridge model related to the Melan equation', 'Enhanced local maximum-entropy approximation for stable meshfree simulations', 'Large dynamic range tracking of an XY compliant nanomanipulator with cross-axis coupling reduction', 'Minimal paths for tubular structure segmentation with coherence penalty and adaptive anisotropy', 'Analytical prediction of wall thickness reduction and forming forces during the radial indentation process in Incremental Profile Forming', 'An Integrated Localization and Control Framework for Multi-Agent Formation', 'Functional characterization of deformation fields', 'Streamline stiffener path optimization (SSPO) for embedded stiffener layout design of non-uniform curved grid-stiffened composite (NCGC) structures', 'A robust method to estimate the time constant of elastographic parameters', 'Comparison of meshing characteristics of helical gears with spalling fault using analytical and finite-element methods', 'Static solution of crack propagation problems in Peridynamics', 'Gradient-enhanced damage modeling in Kirchhoff–Love shells: Application to isogeometric analysis of composite laminates', 'Explicit second order isogeometric discretizations for acoustic wave problems', 'A Total Lagrangian upwind Smooth Particle Hydrodynamics algorithm for large strain explicit solid dynamics', 'Root-finding absorbing boundary conditions for scalar and elastic waves in infinite media', 'A library for wall-modelled large-eddy simulation based on OpenFOAM technology', 'A nonlocal strain gradient theory for dynamic modeling of a rotary thermo piezo electrically actuated nano FG circular plate', 'LIVVkit 2.1: Automated and extensible ice sheet model validation', 'A updating method using strain frequency response function with emphasis on local structure', 'Simultaneously identifying displacement and strain flexibility using long-gauge fiber optic sensors', 'Approximate Robust Output Regulation of Boundary Control Systems', 'Nonlinear higher-order shell theory for incompressible biological hyperelastic materials', 'Self-consistent clustering analysis for multiscale modeling at finite strains', 'Effective elastic moduli of nonspherical particle-reinforced composites with inhomogeneous interphase considering graded evolutions of elastic modulus and porosity', 'Efficient registration of high-resolution feature enhanced point clouds', 'Uncertainty quantification in the mathematical modelling of a suspension strut using BAYESIAN inference', 'Dynamic cobweb models with conformable fractional derivatives', 'Cyber-physical approach to th ...
#
# Cluster 7(N=186)
# ['Lattice Green function methods for atomistic/continuum coupling: Theory and data-sparse implementation', 'A coarse-to-fine decomposing strategy of VMD for extraction of weak repetitive transients in fault diagnosis of rotating machines', 'Fast divergence-conforming reduced basis methods for steady Navier–Stokes flow', 'A higher-order perturbation analysis of the nonlinear Schrödinger equation', 'Dual-Environmental Particle Swarm Optimizer in Noisy and Noise-Free Environments', 'A NURBS-based inverse analysis of thermal expansion induced morphing of thin shells', 'Noisy low-tubal-rank tensor completion', 'Interval-valued data prediction via regularized artificial neural network', 'CFRP Impact Damage Inspection Based on Manifold Learning Using Ultrasonic Induced Thermography', 'Image Estimation in the Presence of Irregular Sampling, Noise, and Pointing Jitter', 'A preliminary geometric structure simplification for Principal Component Analysis', 'Multi harmonic and random stiffness excitation for milling chatter suppression', 'Source enumeration based on a uniform circular array in a determined case', 'Design and implementation of continuous finite-time sliding mode control for 2-DOF inertially stabilized platform subject to multiple disturbances', 'Emergence of death islands in fractional-order oscillators via delayed coupling', 'Dynamic feedrate optimization for parametric toolpath with data-based tracking error prediction', 'Concurrent multi-scale and multi-material topological optimization of vibro-acoustic structures', 'Adaptive vibration suppression of time-varying structures with enhanced FxLMS algorithm', 'Recovering an unknown signal completely submerged in strong noise by a new stochastic resonance method', 'Detection of air leakage into vacuum packages using acoustic measurements and estimation of defect size', 'Time reversal communication using vertical particle velocity and pressure signals in shallow water', 'Frequency-domain analysis for nonlinear systems with time-domain model parameter uncertainty', 'Aperiodic geometry design for DOA estimation of broadband sources using compressive sensing', 'Output-Feedback Adaptive Neural Controller for Uncertain Pure-Feedback Nonlinear Systems Using a High-Order Sliding Mode Observer', 'Tracking of Vehicle Motion on Highways and Urban Roads Using a Nonlinear Observer', 'A continuous random walk model with explicit coherence regularization for image segmentation', 'Identifiability of Dynamical Networks with Singular Noise Spectra', 'Robust Scheduling of Time-Constrained Dual-Arm Cluster Tools with Wafer Revisiting and Activity Time Disturbance', 'Hazard assessment of landslide dams using the evidential reasoning algorithm with multi-scale hesitant fuzzy linguistic information', 'Sensorless predictive control of afe rectifier with robust adaptive inductance estimation', 'Cramér-Rao bound for constrained parameter estimation using Lehmann-unbiasedness', 'Robust FIR State Estimation of Dynamic Processes Corrupted by Outliers', 'Revisiting the MIMO Capacity with Per-Antenna Power Constraint: Fixed-Point Iteration and Alternating Optimization', 'CC Meets FIPS: A Hybrid Test Methodology for First Order Side Channel Analysis', 'Early fault feature extraction of bearings based on Teager energy operator and optimal VMD', 'Multi-object Bayesian filter for jump Markov system under glint noise', 'A Min–Max multiregulator system with stability analysis for aeroengine propulsion control', 'Frequency Shifting and Filtering Algorithm for Power System Harmonic Estimation', 'On the Local Stabilization of Hybrid Limit Cycles in Switched Affine Systems', 'Robust unscented Kalman filter for power system dynamic state estimation with unknown noise statistics', 'Elastic-net regularized latent factor analysis-based models for recommender systems', 'Addressing the Practical Limitations of Noisy-OR Using Conditional Inter-Causal Anti-Correlation with Ranked Nodes', 'Stable Process Approach to Analysi ...
#
# Cluster 8(N=163)
# ['Dynamics and welfare in recombinant growth models with intellectual property rights: A computational method', 'Kalman Filter-based Heuristic Ensemble (KFHE): A new perspective on multi-class ensemble classification using Kalman filters', 'Harnessing Multi-Source Data about Public Sentiments and Activities for Informed Design', 'On the performance evaluation of a hierarchical-structure prototype product using inconsistent prior information and limited test data', 'An integrated workspace for the Cherenkov Telescope Array', 'Interference management for cellular-connected UAVs: A deep reinforcement learning approach', 'Model-based test suite generation for graph transformation system using model simulation and search-based techniques', 'A study on software fault prediction techniques', 'A semi-supervised diagnostic framework based on the surface estimation of faulty distributions', 'Creative design of emergency management scenarios driven by semantics: An application to smart cities', 'Investigation on test effort estimation of mobile applications: Systematic literature review and survey', 'An extensible framework for software configuration optimization on heterogeneous computing systems: Time and energy case study', 'Intelligent Electronic Devices with Collaborative Intrusion Detection Systems', 'When UAV Swarm Meets Edge-Cloud Computing: The QoS Perspective', 'Design and testing of a novel bidirectional energy harvester with single piezoelectric stack', 'Android Malware Detection Using Complex-Flows', 'Bearing-Based Formation Control of a Group of Agents with Leader-First Follower Structure', 'Online Primal-Dual Methods with Measurement Feedback for Time-Varying Convex Optimization', 'Cooperative autonomous search, grasping, and delivering in a treasure hunt scenario by a team of unmanned aerial vehicles', 'Tiny Cyber-Physical Systems for Performance Improvement in the Factory of the Future', 'Deep Q-Learning Aided Networking, Caching, and Computing Resources Allocation in Software-Defined Satellite-Terrestrial Networks', 'Competence-based estimation of activity duration in IT projects', 'Fractional order chattering-free robust adaptive backstepping control technique', 'Multi-dimensional intelligence in smart physical objects', 'Fault detection of rolling element bearings using optimal segmentation of vibrating signals', 'Consensus of delayed multi-agent dynamical systems with stochastic perturbation via dual-stage impulsive approach', 'Programming languages in chemistry: A review of HTML5/JavaScript', 'Review of the pansharpening methods for remote sensing images based on the idea of meta-analysis: Practical discussion and challenges', 'Multiperiod Planning of Distribution Networks under Competitive Electricity Market with Penetration of Several Microgrids Part II: Case Study and Numerical Analysis', 'An elaborated action design research process model', 'An empirical air-to-ground channel model based on passive measurements in LTE', 'A user-oriented language for specifying interconnections between heterogeneous objects in the internet of things', 'Architecture-Based Behavioral Adaptation with Generated Alternatives and Relaxed Constraints', 'Event-Triggered Coordination for Formation Tracking Control in Constrained Space with Limited Communication', 'SIMPM – Upper-level ontology for manufacturing process plan network generation', 'Neural Learning Control of Strict-Feedback Systems Using Disturbance Observer', 'Interactive Nonconvex Pareto Navigator for multiobjective optimization', 'A systematic mapping study of infrastructure as code research', 'Introducing Automated Verification and Validation for Virtualized Network Functions and Services', 'A systematic method for building Internet of Agents applications based on the Linked Open Data approach', 'Methods and tools for policy analysis', 'Reasoning about UML/OCL class diagrams using constraint logic programming and formula', 'A partial adjustment valuation approach with sto ...
#
# Cluster 9(N=110)
# ['Wearable computing for internet of things: A discriminant approach for human activity recognition', 'Ultra-Fast Bloom Filters using SIMD Techniques', 'Intelligence at the Edge of Complex Networks: The Case of Cognitive Transmission Power Control', 'Blockchain and Deep Reinforcement Learning Empowered Intelligent 5G beyond', 'An overview of machine learning approaches in wireless mesh networks', 'Analytical Modeling for Mobility Signalling in Ultradense HetNets', 'Energy Management in RFID-Sensor Networks: Taxonomy and Challenges', 'Throughput Analysis of Vehicular Internet Access via Roadside WiFi Hotspot', 'WiFi sensing with channel state information: A survey', 'A prediction-based charging policy and interference mitigation approach in the wireless powered internet of things', 'Writing in the Air with WiFi Signals for Virtual Reality Devices', 'Human bond communications: Architectures, challenges, and possibilities', 'Coordinated Dispatch of Virtual Energy Storage Systems in Smart Distribution Networks for Loading Management', 'Machine-to-machine communications with massive access: Congestion control', 'A Data-Centric Cognitive Gateway with Distributed MIMO for Future Smart Homes', 'Toward Green IoT: Energy Solutions and Key Challenges', 'Toward Real-Time Control in Future Wireless Networks: Communication-Control Co-Design', 'On Unified Vehicular Communications and Radar Sensing in Millimeter-Wave and Low Terahertz Bands', 'Artificial intelligence inspired transmission scheduling in cognitive vehicular communications and networks', 'Utility-optimal wireless routing in the presence of heavy tails', 'Efficient random access channel evaluation and load estimation in LTE-A with massive MTC', 'A smart caching mechanism for mobile multimedia in information centric networking with edge computing', 'Internet of things mobile-air pollution monitoring system (IoT-Mobair)', 'Challenges in wireless communication for connected sensors and wearable devices used in sport biofeedback applications', 'Green Communication for NOMA-Based CRAN', 'Optimal utility of vehicles in LTE-V Scenario: An immune clone-based spectrum allocation approach', 'Coordinated multi-point downlink transmission for dense small cell networks', 'A Secure and Efficient Location-based Service Scheme for Smart Transportation', 'Planning UAV activities for efficient user coverage in disaster areas', 'MEC-Assisted panoramic VR video streaming over millimeter wave mobile networks', 'Toward Intelligent Vehicular Networks: A Machine Learning Framework', 'A near maximum likelihood performance modified firefly algorithm for large MIMO detection', 'Orbital angular momentum for wireless communications', 'Joint Multi-Beam Training and Codebook Design for Indoor High-Throughput Transmissions under Limited Training Steps', 'Planning and operational energy optimization solutions for smart buildings', 'Multimodel framework for indoor localization under mobile edge computing environment', 'Social-Aware Data Dissemination via Device-to-Device Communications: Fusing Social and Mobile Networks with Incentive Constraints', 'Two metaheuristics for routing and spectrum allocation in cloud-ready survivable elastic optical networks', 'Harnessing the power of big data analytics in the cloud to support learning analytics in mobile learning environment', 'DIPS: Dual-Interface Dual-Pipeline Scheduling for Energy-Efficient Multihop Communications in IoT', 'An Energy Saving Small Cell Sleeping Mechanism with Cell Range Expansion in Heterogeneous Networks', 'Heterogeneous Space and Terrestrial Integrated Networks for IoT: Architecture and Challenges', 'Blockchain-enabled data collection and sharing for industrial iot with deep reinforcement learning', 'Powering the Internet of Things through Light Communication', 'Future of Ultra-Dense Networks Beyond 5G: Harnessing Heterogeneous Moving Cells', 'Machine learning for wireless connectivity and security of cellular-connected uavs', 'Exploring Microser ...
#
# Cluster 10(N=116)
# ['Multimodal Structural Distribution of the p53 C-Terminal Domain upon Binding to S100B via a Generalized Ensemble Method: From Disorder to Extradisorder', 'Inferring MicroRNA targets based on restricted boltzmann machines', 'Pathway-specific protein domains are predictive for human diseases', 'DeepGSR: An optimized deep-learning structure for the recognition of genomic signals and regions', 'Experimentally Derived and Computationally Optimized Backbone Conformational Statistics for Blocked Amino Acids', 'Identifying individual risk rare variants using protein structure guided local tests (POINT)', 'H3K27me3 Signal in the Cis Regulatory Elements Reveals the Differentiation Potential of Progenitors During Drosophila Neuroglial Development', 'Predicting Protein Dimer Structures Using MELD × MD', 'CSBFinder: Discovery of colinear syntenic blocks across thousands of prokaryotic genomes', 'MiES: Predicting the essentiality of miRNAs with machine learning and sequence features', 'gFACs: Gene Filtering, Analysis, and Conversion to Unify Genome Annotations Across Alignment and Gene Prediction Frameworks', 'Identifying author heritage using surname data: An application for Russian surnames', 'On the viability of unsupervised T-cell receptor sequence clustering for epitope preference', 'Mapping DNA sequence to transcription factor binding energy in vivo', 'Cosolvent-Enhanced Sampling and Unbiased Identification of Cryptic Pockets Suitable for Structure-Based Drug Design', 'RNAvista: A webserver to assess RNA secondary structures with non-canonical base pairs', 'Post genome-wide association analysis: Dissecting computational pathway/network-based approaches', 'Computational analysis of kinase inhibitor selectivity using structural knowledge', 'OPA2Vec: Combining formal and informal content of biomedical ontologies to improve similarity-based prediction', 'Synergizing CRISPR/Cas9 off-target predictions for ensemble insights and practical applications', 'PolyQTL: Bayesian multiple eQTL detection with control for population structure and sample relatedness', 'Exploring E-cadherin-peptidomimetics interaction using NMR and computational studies', 'Pattern recognition analysis on long noncoding RNAs: A tool for prediction in plants', 'BrainEXP: A database featuring with spatiotemporal expression variations and co-expression organizations in human brains', 'A computational framework to assess genome-wide distribution of polymorphic human endogenous retrovirus-k in human populations', 'RNAdetect: Efficient computational detection of novel non-coding RNAs', 'High precision protein functional site detection using 3D convolutional neural networks', 'Towards region-specific propagation of protein functions', 'Determination of Two-Photon-Absorption Cross Sections Using Time-Dependent Density Functional Theory Tight Binding: Application to Fluorescent Protein Chromophores', 'KEDDY: A knowledge-based statistical gene set test method to detect differential functional protein-protein interactions', 'Phylo-PFP: Improved automated protein function prediction using phylogenetic distance of distantly related sequences', 'Determination of sets of covariating gene expression using graph analysis on pairwise expression ratios', 'AbPredict 2: A server for accurate and unstrained structure prediction of antibody variable domains', 'The fitness cost and benefit of phase-separated protein deposits', 'Protease target prediction via matrix factorization', 'The intrinsic dimension of protein sequence evolution', 'A deep proteome and transcriptome abundance atlas of 29 healthy human tissues', 'Defining the RNA interactome by total RNA-associated protein purification', 'Global Quantitative Mapping of Enhancers in Rice by STARR-seq', 'A quantitative map of protein sequence space for the cis-defensin superfamily', 'The breadth of HIV-1 neutralizing antibodies depends on the conservation of key sites in their epitopes', 'Structural Analysis of the Active Site and DNA Bindi ...
#
# Cluster 11(N=52)
# ['Taming the IoT data deluge: An innovative information-centric service model for fog computing applications', 'APPA: An anonymous and privacy preserving data aggregation scheme for fog-enhanced IoT', 'Towards traffic load balancing in drone-assisted communications for IoT', 'DOTS: Delay-optimal task scheduling among voluntary nodes in fog networks', 'Availability-aware service placement policy in fog computing based on graph partitions', 'Fog Computing Enabled Future Mobile Communication Networks: A Convergence of Communication and Computing', 'Privacy-Preserving Authentication and Data Aggregation for Fog-Based Smart Grid', 'AIPNet: Image-to-Image Single Image Dehazing with Atmospheric Illumination Prior', 'Fog-based computing and storage offloading for data synchronization in IoT', 'Secure and privacy-preserving orchestration and delivery of fog-enabled IoT services', 'An Attribute Credential Based Public Key Scheme for Fog Computing in Digital Manufacturing', 'A Privacy-Preserving and Verifiable Querying Scheme in Vehicular Fog Data Dissemination', 'Traffic and Computation Co-Offloading with Reinforcement Learning in Fog Computing for Industrial Applications', 'Energy-Efficient Adaptive Resource Management for Real-Time Vehicular Cloud Services', 'Data-driven network intelligence for anomaly detection', 'Application Component Placement in NFV-Based Hybrid Cloud/Fog Systems with Mobile Fog Nodes', 'Green large-scale fog computing resource allocation using joint benders decomposition, dinkelbach algorithm, ADMM, and branch-and-bound', 'UAV-Enabled spatial data sampling in large-scale iot systems using denoising autoencoder neural network', 'Fog data analytics: A taxonomy and process model', 'Security and privacy preservation in fog-based crowd sensing on the internet of vehicles', 'Deployment and Dimensioning of Fog Computing-Based Internet of Vehicle Infrastructure for Autonomous Driving', 'Secure Real-Time Control Through Fog Computation', 'Secure fog-assisted crowdsensing with collusion resistance: From data reporting to data requesting', 'Model and algorithms for the planning of fog computing networks', 'Design of secure key management and user authentication scheme for fog computing services', 'Enabling technologies for fog computing in healthcare IoT systems', 'Computation Resource Allocation and Task Assignment Optimization in Vehicular Fog Computing: A Contract-Matching Approach', 'Distributed Online Learning of Fog Computing under Nonuniform Device Cardinality', 'Reliable and Secure Vehicular Fog Service Provision', 'Radio over Cloud (RoC): Cloud-Assisted Distributed Beamforming for Multi-Class Traffic', 'Cloud removal in remote sensing images using nonnegative matrix factorization and error correction', 'DATS: Dispersive stable task scheduling in heterogeneous fog networks', 'BLA: Blockchain-assisted lightweight anonymous authentication for distributed vehicular fog services', 'Folo: Latency and quality optimized task allocation in vehicular fog computing', 'Treasure collection on foggy islands: Building secure network archives for internet of things', 'Encryption protocol for resource-constrained devices in fog-based IoT Using one-time pads', 'Modeling industry 4.0 based fog computing environments for application analysis and deployment', 'Single Image Defogging Based on Illumination Decomposition for Visual Maritime Surveillance', 'CPS data streams analytics based on machine learning for Cloud and Fog Computing: A survey', 'An optimal relay scheme for outage minimization in fog-based internet-of-things (IoT) Networks', 'An online optimization framework for distributed fog network formation with minimal latency', 'Privacy-preserving public auditing for secure data storage in fog-to-cloud computing', 'On Positioning Performance for the Narrow-Band Internet of Things: How Participating eNBs Impact?', 'FEMTO: Fair and energy-minimized task offloading for fog-enabled IoT networks', 'Vehicular fog computing: Enabling r ...
#
# Cluster 12(N=204)
# ...
#
# Cluster 98(N=170)
# ['Potential-Energy Surfaces for Ring-Puckering Motions of Flexible Cyclic Molecules through Cremer-Pople Coordinates: Computation, Analysis, and Fitting', 'Numerical and Theoretical Aspects of the DMRG-TCC Method Exemplified by the Nitrogen Dimer', 'Simulation of Inelastic Neutron Scattering Spectra Using OCLIMAX', "Wide ranging equation of state with Tartarus: A hybrid Green's function/orbital based average atom code", 'Manual of BlackMax. A black-hole event generator with rotation, recoil, split branes, and brane tension. Version 2.02', 'Ab Initio Flexible Force Field for Metal-Organic Frameworks Using Dummy Model Coordination Bonds', 'A DFT/ZORA Study of Cadmium Magnetic Shielding Tensors: Analysis of Relativistic Effects and Electronic-State Approximations', 'A GROMOS Force Field for Furanose-Based Carbohydrates', 'Exciton-Phonon Interaction Model for Singlet Fission in Prototypical Molecular Crystals', 'Hyperconjugation', 'Mesoscale Electrostatics Driving Particle Dynamics in Nonhomogeneous Dielectrics', 'RIS 4: A program for relativistic isotope shift calculations', 'Toward Automated Variational Computation of Rovibrational Resonances, Including a Case Study of the H2 Dimer', 'NMR Shielding Tensors and Chemical Shifts in Scalar-Relativistic Local Exact Two-Component Theory', 'Modelings and mechanism analysis underlying both the 4D Euler equations and Hamiltonian conservative chaotic systems', 'A hybrid particle swarm optimization algorithm for load balancing of MDS on heterogeneous computing systems', 'From Molecular Fragments to the Bulk: Development of a Neural Network Potential for MOF-5', 'Independent perturbations for physics parametrization tendencies in a convection-permitting ensemble (pSPPT)', 'Quadrupolar 14 N NMR Relaxation from Force-Field and Ab Initio Molecular Dynamics in Different Solvents', 'Nonequilibrium Environment Dynamics in a Frequency-Dependent Polarizable Embedding Model', 'Nonequilibrium Solvent Polarization Effects in Real-Time Electronic Dynamics of Solute Molecules Subject to Time-Dependent Electric Fields: A New Feature of the Polarizable Continuum Model', 'Efficient computation of Coulomb and exchange integrals for multi-million atom nanostructures', 'All-Electron Quantum Monte Carlo with Jastrow Single Determinant Ansatz: Application to the Sodium Dimer', 'Phase Equilibria of Solid and Fluid Phases from Molecular Dynamics Simulations with Equilibrium and Nonequilibrium Free Energy Methods', 'Ab initio Potential Energy Curve for the Ground State of Beryllium Dimer', 'On power law scaling dynamics for time-fractional phase field models during coarsening', 'Analysis and optimization of a novel planar 5R parallel mechanism with variable actuation modes', 'Photophysics of Molecular Aggregates from Excited State Diabatization', 'Non-Orthogonal Configuration Interaction with Single Substitutions for Core-Excited States: An Extension to Doublet Radicals', 'i-PI 2.0: A universal force engine for advanced molecular simulations', 'Close Relationships between NMR J-Coupling Alternation (JCA) and Molecular Properties of Carbon Chains', 'Modeling Nucleation and Growth of ZnO Nanoparticles in a Low Temperature Plasma by Reactive Dynamics', 'On Achieving High Accuracy in Quantum Chemical Calculations of 3 d Transition Metal-Containing Systems: A Comparison of Auxiliary-Field Quantum Monte Carlo with Coupled Cluster, Density Functional Theory, and Experiment for Diatomic Molecules', 'Multicomponent Coupled Cluster Singles and Doubles Theory within the Nuclear-Electronic Orbital Framework', 'Assessment of GAFF2 and OPLS-AA General Force Fields in Combination with the Water Models TIP3P, SPCE, and OPC3 for the Solvation Free Energy of Druglike Organic Molecules', 'Collective dynamics and energy aspects of star-coupled Hindmarsh–Rose neuron model with electrical, chemical and field couplings', 'Deriving Force-Field Parameters from First Principles Using a Polarizable and Higher Order Dispersion Model', 'A Sim ...
#
# Cluster 99(N=123)
# ['Edge cracking prevention in 2507 super duplex stainless steel by twin-roll strip casting and its microstructure and properties', 'Microstructure, tensile properties and corrosion behavior of friction stir processed Mg-9Li-1Zn alloy', 'Elaboration of oxide dispersion strengthened Fe-14Cr stainless steel by selective laser melting', 'Corrosion resistance of welded joints of X5CrNi18-10 stainless steel', 'Microstructural evolution and characteristics of bonding zone in multilayer laser cladding of Fe-based coating', 'Effect of coating type on microstructure and mechanical behavior of resistance spot welds of thin X626 aluminum sheet to low carbon steel', 'Microstructures of longitudinal/transverse welds and back-end defects and their influences on the corrosion resistance and mechanical properties of aluminum alloy extrusion profiles', 'A Brief Review and a New Graph-Based Image Analysis for Concrete Crack Quantification', 'Thermoplastic processing and debinding behavior of NbC-M2 high speed steel cemented carbide', 'AZ31B/7075-T6 alloys friction stir lap welding with a zinc interlayer', 'Microstructure and mechanical properties of 6061/7N01 CMT+P joints', 'An experimental investigation on the deformation and post-formed strength of heat-treatable aluminium alloys using different elevated temperature forming processes', 'Mechanical reliability of TWIP steel spot weldings', 'Cost-driven build orientation and bin packing of parts in Selective Laser Melting (SLM)', 'Flat friction stir spot welding of three 6061-T6 aluminum sheets', 'Crack identification at welding joint with a new smart coating sensor and entropy', 'Observations of repair process by friction stitch welding in simulated wet conditions—Flaws, microstructure and hardness evolutions in overlapping welds', 'Effect of the laser power on the mechanical performance of the laser spot welds in dual phase steels', 'A mathematical model to predict thickness distribution and formability of incremental forming combined with stretch forming', 'In-situ ultrasonic detection of resistance spot welding quality using embedded probe', 'Friction stir processing of AlSi10Mg parts produced by selective laser melting', 'Effects of brazing temperature and post weld heat treatment on 7075 alloy brazed joints', 'Laser seal welding of end plug to thin-walled nanostructured high-strength molybdenum alloy cladding with a zirconium interlayer', 'Influences of depositing materials, processing parameters and heating conditions on material characteristics of laser-cladded hypereutectoid rails', 'An approach to enhancement of Mg alloy joint performance by additional pass of friction stir processing', 'Ultrasonic sensor signals and self organized mapping with nearest neighbors for the microstructural characterization of thermally-aged Inconel 625 alloy', 'Miniaturized tube fixed plug drawing: Determination of the friction coefficients and drawing limit of 316 LVM stainless steel', 'Weld zone and residual stress development in AA7050 stationary shoulder friction stir T-joint weld', 'Effect of beam oscillation on porosity and intermetallics of electron beam welded DP600-steel to Al 5754-alloy', 'An automatic personalized internal fixation plate modeling framework for minimally invasive long bone fracture surgery based on pre-registration with maximum common subgraph strategy', 'Capacitor discharge welding of nuts to steel sheets', 'Microstructure and properties of transient liquid phase bonding of AM60 Mg alloy to 304 stainless steel with Zn interlayer', 'Effects of interface gap and shielding gas on the quality of alloy AA6061 fiber laser lap weldings', 'Theoretical and experimental investigations of ultra-short pulse laser interaction on Ti6Al4V alloy', 'Joining of tubular carbon fiber-reinforced plastic/aluminum by magnetic pulse welding', 'Residual stresses of friction melt bonded aluminum/steel joints determined by neutron diffraction', 'Schedule and electrode design for resistance spot weld bondi ...
#
# Cluster 100(N=152)
# ['Early Detection of Mild Cognitive Impairment With In-Home Monitoring Sensor Technologies Using Functional Measures: A Systematic Review', 'Multi-scale dictionary learning for ocular artifact reduction from single-channel electroencephalograms', 'DoGNet: A deep architecture for synapse detection in multiplexed fluorescence images', 'Audiovisual Analysis of Music Performances: Overview of an Emerging Field', 'Perception Coordination Network: A Neuro Framework for Multimodal Concept Acquisition and Binding', 'Contrasting the effects of adaptation and synaptic filtering on the timescales of dynamics in recurrent networks', 'A CRNN module for hand pose estimation', 'Myopic control of neural dynamics', 'Making Music More Accessible for Cochlear Implant Listeners: Recent Developments', 'Quasiperiodic rhythms of the inferior olive', 'Interneuronal gamma oscillations in hippocampus via adaptive exponential integrate-and-fire neurons', 'Discovering hierarchical common brain networks via multimodal deep belief network', 'Estimating coupling strength between multivariate neural series with multivariate permutation conditional mutual information', 'Repetitive motion compensation for real time intraoperative video processing', 'A survey on brain biometrics', 'Boolean model of growth signaling, cell cycle and apoptosis predicts the molecular mechanism of aberrant cell cycle progression driven by hyperactive PI3K', 'Reward-driven changes in striatal pathway competition shape evidence evaluation in decision-making', 'A Subject-Driven Unsupervised Hidden Semi-Markov Model and Gaussian Mixture Model for Heart Sound Segmentation', 'Synchronization of Slow Cortical Rhythms during Motor Imagery-Based Brain-Machine Interface Control', 'A Neuronal Network Model of the Primate Visual System: Color Mechanisms in the Retina, LGN and V1', 'Multistability of Delayed Hybrid Impulsive Neural Networks With Application to Associative Memories', 'Morphological Neuron Classification Based on Dendritic Tree Hierarchy', 'An introduction to brain emotional learning inspired models (BELiMs) with an example of BELiMs’ applications', 'Spike burst-pause dynamics of Purkinje cells regulate sensorimotor adaptation', 'Modeling and MEG evidence of early consonance processing in auditory cortex', 'Electromagnetic induction on a map-based action potential model', 'Spike Timing or Rate? Neurons Learn to Make Decisions for Both Through Threshold-Driven Plasticity', 'Synaptic plasticity onto inhibitory neurons as a mechanism for ocular dominance plasticity', 'Signal Processing Advances Consumer Electronics: New Research Impacts and Improves the Way Users Interact with Mobile and Wearable Devices in Daily Life [Special Reports]', 'Nonlinear effect of biological feedback on brain attentional state', 'Lateral Inhibition Organizes Beta Attentional Modulation in the Primary Visual Cortex', 'Chimera states of neuron networks with adaptive coupling', 'Generalized Hidden-Mapping Transductive Transfer Learning for Recognition of Epileptic Electroencephalogram Signals', 'Roles for globus pallidus externa revealed in a computational model of action selection in the basal ganglia', 'Dynamic balance between vesicle transport and microtubule growth enables neurite outgrowth', 'Recognizing Brain States Using Deep Sparse Recurrent Neural Network', 'Parameter estimation and identifiability in a neural population model for electro-cortical activity', 'Resurgent Na+ current offers noise modulation in bursting neurons', 'Uncovering functional signature in neural systems via random matrix theory', 'Electrical synapses regulate both subthreshold integration and population activity of principal cells in response to transient inputs within canonical feedforward circuits', 'Visualization of neuronal structures in wide-field microscopy brain images', 'Characterizing Regularization Techniques for Spatial Filter Optimization in Oscillatory EEG Regression Problems: Guidelines Derived from Simulation and ...

# %%
scopus_2019_life.desc_clusters(scopus_2019_life.clustered_subjects)
# Out:
# Cluster 1(N=110)
# ['General Computer Science', 'General Computer Science', 'Aerospace Engineering', 'Aerospace Engineering', 'Information Systems', 'Computer Networks and Communications', 'Software', 'General Computer Science', 'General Mathematics', 'General Computer Science', 'Civil and Structural Engineering', 'General Computer Science', 'Artificial Intelligence', 'General Mathematics', 'Computer Science Applications', 'Numerical Analysis', 'General Computer Science', 'Civil and Structural Engineering', 'General Computer Science', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'General Mathematics', 'Information Systems and Management', 'General Computer Science', 'Computational Theory and Mathematics', 'Information Systems', 'General Computer Science', 'General Computer Science', 'Electrical and Electronic Engineering', 'General Computer Science', 'General Engineering', 'Computers in Earth Sciences', 'Aerospace Engineering', 'General Computer Science', 'Information Systems', 'Computer Science Applications', 'Information Systems', 'Civil and Structural Engineering', 'Information Systems', 'General Computer Science', 'General Computer Science', 'Aerospace Engineering', 'General Computer Science', 'Computer Science Applications', 'Information Systems', 'General Computer Science', 'Numerical Analysis', 'General Computer Science', 'General Computer Science', 'Applied Mathematics', 'Information Systems', 'Information Systems', 'General Mathematics', 'Civil and Structural Engineering', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'General Computer Science', 'Computer Science Applications', 'General Computer Science', 'Information Systems', 'Electrical and Electronic Engineering', 'Information Systems and Management', 'Applied Mathematics', 'General Computer Science', 'Mechanical Engineering', 'General Computer Science', 'General Computer Science', 'Applied Mathematics', 'Computer Science Applications', 'General Computer Science', 'Civil and Structural Engineering', 'Software', 'Information Systems and Management', 'General Computer Science', 'General Computer Science', 'Electrical and Electronic Engineering', 'Information Systems', 'General Computer Science', 'Civil and Structural Engineering', 'Numerical Analysis', 'Civil and Structural Engineering', 'General Computer Science', 'Aerospace Engineering', 'Aerospace Engineering', 'Aerospace Engineering', 'General Computer Science', 'Information Systems', 'Information Systems', 'Artificial Intelligence', 'General Computer Science', 'Information Systems', 'Civil and Structural Engineering', 'General Earth and Planetary Sciences', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'General Computer Science', 'Information Systems', 'Civil and Structural Engineering', 'Applied Mathematics', 'Information Systems', 'Civil and Structural Engineering', 'General Computer Science', 'General Computer Science', 'General Computer Science', 'Aerospace Engineering', 'Civil and Structural Engineering', 'Information Systems', 'Software']
#
# Cluster 2(N=170)
# ['Signal Processing', 'Signal Processing', 'Artificial Intelligence', 'Signal Processing', 'General Engineering', 'Information Systems', 'Cellular and Molecular Neuroscience', 'Signal Processing', 'Ecological Modeling', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Information Systems', 'Software', 'Physical and Theoretical Chemistry', 'General Engineering', 'Artificial Intelligence', 'Computer Science Applications', 'Control and Systems Engineering', 'Applied Mathematics', 'Biochemistry', 'Computers in Earth Sciences', 'General Engineering', 'Management Information Systems', 'Computer Vision and Pattern Recognition', 'General Engineering', 'General Engineering', 'Computational Theory and Mathematics', 'Artificial Intelligence', 'Artificial Intelligence', 'Computer Science Applications', nan, 'Biochemistry', 'Computer Graphics and Computer-Aided Design', 'Cellular and Molecular Neuroscience', 'General Computer Science', 'Computer Graphics and Computer-Aided Design', 'Artificial Intelligence', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Safety, Risk, Reliability and Quality', 'Information Systems and Management', 'Computer Science Applications', 'Applied Mathematics', 'Information Systems', 'Human-Computer Interaction', 'Computational Theory and Mathematics', 'Electrical and Electronic Engineering', 'Ecological Modeling', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Artificial Intelligence', 'Information Systems', 'Control and Systems Engineering', 'General Computer Science', 'Management Information Systems', 'Computational Theory and Mathematics', 'Artificial Intelligence', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Biotechnology', 'Software', 'Applied Mathematics', 'Information Systems', 'Signal Processing', 'Biochemistry', 'Management Information Systems', 'Software', 'Artificial Intelligence', 'Software', 'Information Systems', 'Electrical and Electronic Engineering', 'General Engineering', 'General Engineering', 'Ecological Modeling', 'Human-Computer Interaction', 'Artificial Intelligence', 'General Engineering', 'Cellular and Molecular Neuroscience', 'Signal Processing', 'Computer Science Applications', 'Biochemistry', 'Software', 'Computer Science Applications', 'Mechanical Engineering', 'Management Information Systems', 'Electrical and Electronic Engineering', 'Artificial Intelligence', 'Software', 'Information Systems', 'Artificial Intelligence', 'Artificial Intelligence', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Signal Processing', 'Information Systems and Management', 'Information Systems and Management', 'Signal Processing', 'Software', 'General Engineering', 'Software', 'Computer Graphics and Computer-Aided Design', 'Human-Computer Interaction', 'Electrical and Electronic Engineering', 'Management Information Systems', 'Management Information Systems', 'Artificial Intelligence', 'Artificial Intelligence', 'Computer Vision and Pattern Recognition', 'Artificial Intelligence', 'Biochemistry', 'Human-Computer Interaction', 'Electrical and Electronic Engineering', 'Hardware and Architecture', 'Management Information Systems', 'Computer Science Applications', 'Signal Processing', 'Applied Mathematics', 'Human-Computer Interaction', 'Artificial Intelligence', 'Computer Science Applications', 'General Computer Science', 'Hardware and Architecture', 'Artificial Intelligence', 'Artificial Intelligence', 'Artificial Intelligence', 'General Engineering', 'Computer Science Applications', 'Signal Processing', 'Safety, Risk, Reliability and Quality', 'Applied Mathematics', 'Cellular and Molecular Neuroscience', 'Physical and Theoretical Chemistry', 'Information Systems and Management', 'Computer Science Applications', 'Art ...
#
# Cluster 3(N=66)
# ['General Engineering', 'General Earth and Planetary Sciences', 'Computers in Earth Sciences', 'Computer Science Applications', 'General Engineering', 'Information Systems and Management', 'Cellular and Molecular Neuroscience', 'Aerospace Engineering', 'Artificial Intelligence', 'Aerospace Engineering', 'Computer Graphics and Computer-Aided Design', 'Information Systems', 'Management Information Systems', 'Information Systems', 'Aerospace Engineering', 'Computer Science Applications', 'Signal Processing', 'Aerospace Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Aerospace Engineering', 'Computers in Earth Sciences', 'Computer Science Applications', 'Information Systems and Management', 'Software', 'Ecological Modeling', 'Artificial Intelligence', 'Mechanical Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Software', 'Hardware and Architecture', 'Software', 'Software', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Software', 'Computer Science Applications', 'Artificial Intelligence', 'Electrical and Electronic Engineering', 'Control and Systems Engineering', 'Management Information Systems', 'Aerospace Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Mechanical Engineering', 'Mechanical Engineering', 'Information Systems', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Artificial Intelligence', 'Electrical and Electronic Engineering', 'Computers in Earth Sciences', 'Artificial Intelligence', 'Computer Science Applications', 'Control and Systems Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Computer Networks and Communications', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Computer Graphics and Computer-Aided Design', 'Applied Mathematics']
#
# Cluster 4(N=246)
# ['Electrical and Electronic Engineering', 'Computer Science Applications', 'Applied Mathematics', 'Artificial Intelligence', 'Aerospace Engineering', 'Aerospace Engineering', 'Applied Mathematics', 'Information Systems', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Software', 'Software', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Civil and Structural Engineering', 'Civil and Structural Engineering', 'Aerospace Engineering', 'Civil and Structural Engineering', 'Computer Science Applications', 'Hardware and Architecture', 'Electrical and Electronic Engineering', 'Artificial Intelligence', 'Civil and Structural Engineering', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Software', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Software', 'Electrical and Electronic Engineering', 'Artificial Intelligence', 'Applied Mathematics', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Artificial Intelligence', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Civil and Structural Engineering', 'Biotechnology', 'Civil and Structural Engineering', 'Information Systems', 'Aerospace Engineering', 'Control and Systems Engineering', 'General Engineering', 'Aerospace Engineering', 'Applied Mathematics', 'Applied Mathematics', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Applied Mathematics', 'Aerospace Engineering', 'Civil and Structural Engineering', 'Computer Graphics and Computer-Aided Design', 'Management Information Systems', 'Biotechnology', 'Software', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Signal Processing', 'Aerospace Engineering', 'Aerospace Engineering', 'Aerospace Engineering', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Applied Mathematics', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Computer Graphics and Computer-Aided Design', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Civil and Structural Engineering', 'Computer Graphics and Computer-Aided Design', 'Software', 'Software', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Aerospace Engineering', 'Applied Mathematics', 'Computer Graphics and Computer-Aided Design', 'Electrical and Electronic Engineering', 'Computer Vision and Pattern Recognition', 'Applied Mathematics', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Computer Networks and Communications', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Applied Mathematics', 'Applied Mathematics', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Applied Mathematics', 'Applied Mathematics', 'Applied Mathematics', 'Aerospace Engineering', 'Software', 'Control and Systems Engineering', 'Aerospace Engineering', 'Electrical and Electronic Engi ...
#
# Cluster 5(N=119)
# ['Arts and Humanities (miscellaneous)', 'Computer Networks and Communications', 'Information Systems', 'Information Systems', 'Software', 'Computer Networks and Communications', 'Computer Science Applications', 'Safety, Risk, Reliability and Quality', 'General Computer Science', 'Hardware and Architecture', 'Software', 'General Engineering', 'Computer Science Applications', 'Computer Networks and Communications', 'Information Systems', 'Artificial Intelligence', 'Computer Science Applications', 'Aerospace Engineering', 'Applied Mathematics', 'Information Systems', 'Arts and Humanities (miscellaneous)', 'Artificial Intelligence', 'Information Systems', 'Information Systems', 'Computer Science Applications', 'Software', 'Information Systems', 'Information Systems', 'Information Systems', 'Information Systems', 'Electrical and Electronic Engineering', 'General Mathematics', 'Software', 'Computer Science Applications', 'General Computer Science', 'Applied Mathematics', 'Software', 'Computer Networks and Communications', 'Software', 'Software', 'Information Systems', 'Theoretical Computer Science', 'Arts and Humanities (miscellaneous)', 'General Engineering', 'Computer Science Applications', 'Library and Information Sciences', 'General Computer Science', 'General Computer Science', 'Arts and Humanities (miscellaneous)', 'Human-Computer Interaction', 'Computer Science Applications', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'General Computer Science', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Computer Networks and Communications', 'Electrical and Electronic Engineering', 'Computer Networks and Communications', 'Computational Theory and Mathematics', 'Computer Networks and Communications', 'Computer Science Applications', 'Information Systems', 'Computer Networks and Communications', 'Information Systems', 'Civil and Structural Engineering', 'General Engineering', 'Computer Science Applications', 'Computer Networks and Communications', 'General Engineering', 'Information Systems and Management', 'Computer Science Applications', 'Signal Processing', 'Safety, Risk, Reliability and Quality', 'Computer Science Applications', 'Library and Information Sciences', 'Aerospace Engineering', 'Management Information Systems', 'Aerospace Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Software', 'Computer Science Applications', 'Software', 'Hardware and Architecture', 'Computer Science Applications', 'Computer Science Applications', 'Software', 'Information Systems', 'Signal Processing', 'Electrical and Electronic Engineering', 'Artificial Intelligence', 'Computer Networks and Communications', 'Computer Networks and Communications', 'Computer Networks and Communications', 'Computers in Earth Sciences', 'Electrical and Electronic Engineering', 'Information Systems', 'Arts and Humanities (miscellaneous)', 'Software', 'Arts and Humanities (miscellaneous)', 'Hardware and Architecture', 'Biotechnology', 'Computer Networks and Communications', 'Aerospace Engineering', 'Aerospace Engineering', 'Arts and Humanities (miscellaneous)', 'Software', 'Software', 'Computer Science Applications', 'Software', 'Aerospace Engineering', 'Computer Networks and Communications', 'Arts and Humanities (miscellaneous)', 'Computer Science Applications', 'Computer Networks and Communications', 'Software', 'Software']
#
# Cluster 6(N=178)
# ['Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computers in Earth Sciences', 'Numerical Analysis', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Applied Mathematics', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'General Earth and Planetary Sciences', 'Numerical Analysis', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Software', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Hardware and Architecture', 'Civil and Structural Engineering', 'General Earth and Planetary Sciences', 'Civil and Structural Engineering', 'Civil and Structural Engineering', 'Control and Systems Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Applied Mathematics', 'Civil and Structural Engineering', 'Control and Systems Engineering', 'Computer Science Applications', 'General Earth and Planetary Sciences', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Software', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Information Systems and Management', 'Physical and Theoretical Chemistry', 'Computer Science Applications', 'Information Systems', 'Applied Mathematics', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Software', 'Computer Science Applications', 'Computer Science Applications', 'Applied Mathematics', 'Computer Science Applications', 'Ecological Modeling', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Artificial Intelligence', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Applied Mathematics', 'Civil and Structural Engineering', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Hardware and Architecture', 'Computer Science Applications', 'Computer Science Applications', 'Physical and Theoretical Chemistry', 'Computer Science Applications', 'Artificial Intelligence', 'Civil and Structural Engineering', 'Computer Science Applications', 'Hardware and Architecture', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Civil and Structural Engineering', 'Civil and Structural Engineering', 'General Computer Science', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Civil and Structural Engineering', 'Civil and Structural Engineering', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Hardware and Architecture', 'Computer Science Applications', 'Civil and Structural Engineering', 'Numerical Analysis', 'Information Systems', 'Computer Science Ap ...
#
# Cluster 7(N=186)
# ['Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Numerical Analysis', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Information Systems', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Civil and Structural Engineering', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Numerical Analysis', 'Civil and Structural Engineering', 'Computer Science Applications', 'Civil and Structural Engineering', 'Numerical Analysis', 'Civil and Structural Engineering', 'Software', 'Control and Systems Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Computer Graphics and Computer-Aided Design', 'Control and Systems Engineering', 'Control and Systems Engineering', 'Software', 'Information Systems', 'Electrical and Electronic Engineering', 'Information Systems', 'Applied Mathematics', 'Computational Theory and Mathematics', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Information Systems', 'Control and Systems Engineering', 'General Computer Science', 'Computer Science Applications', 'Computer Science Applications', 'Control and Systems Engineering', 'Computer Science Applications', 'Civil and Structural Engineering', 'Signal Processing', 'Applied Mathematics', 'Civil and Structural Engineering', 'General Computer Science', 'Cellular and Molecular Neuroscience', 'Civil and Structural Engineering', 'Artificial Intelligence', 'Management Information Systems', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Artificial Intelligence', 'Applied Mathematics', 'Information Systems', 'Control and Systems Engineering', 'General Engineering', 'Civil and Structural Engineering', 'Cognitive Neuroscience', 'Cellular and Molecular Neuroscience', 'Applied Mathematics', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Civil and Structural Engineering', 'Software', 'Applied Mathematics', 'Computer Science Applications', 'Civil and Structural Engineering', 'Civil and Structural Engineering', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Civil and Structural Engineering', 'Biochemistry', 'Computational Theory and Mathematics', 'Computer Science Applications', 'Civil and Structural Engineering', 'Control and Systems Engineering', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Computer Graphics and Computer-Aided Design', 'General Mathematics', 'Numerical Analysis', 'Civil and Structural Engineering', 'Software', 'General Mathematics', 'Civil and Structural Engineering', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Civil and Structural Engineering', 'Computer Science Applications', 'General Computer Science', 'Physical and Theoretical Chemistry', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Information Systems', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Numerical Analysis', 'Applied Mathematics', 'Information Systems', 'Civil and Structural Engineering', 'General Computer Science', 'Numerical Analysis', 'Signal Processing', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Applied Mathematics', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Software', 'Management Information Systems', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Civil and Structural Engineering', 'Electrical and Electronic Engineering', 'Control and Systems Engineerin ...
#
# Cluster 8(N=163)
# ['Numerical Analysis', 'Artificial Intelligence', 'Computer Science Applications', 'Artificial Intelligence', 'Computer Networks and Communications', 'Applied Mathematics', 'Software', 'Artificial Intelligence', 'Information Systems', 'Hardware and Architecture', 'Software', 'Software', 'General Computer Science', 'Information Systems', 'Civil and Structural Engineering', 'Software', 'Control and Systems Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Information Systems', 'Aerospace Engineering', 'Information Systems and Management', 'Applied Mathematics', 'Theoretical Computer Science', 'Civil and Structural Engineering', 'Applied Mathematics', 'Computer Science Applications', 'Software', 'Information Systems', 'Library and Information Sciences', 'Aerospace Engineering', 'Computer Science Applications', 'Hardware and Architecture', 'Electrical and Electronic Engineering', 'General Mathematics', 'Computer Science Applications', 'Information Systems and Management', 'Software', 'Electrical and Electronic Engineering', 'Computer Networks and Communications', 'General Computer Science', 'Hardware and Architecture', 'Information Systems and Management', 'Numerical Analysis', 'General Computer Science', 'Software', 'General Computer Science', 'Signal Processing', 'Applied Mathematics', 'Computer Science Applications', 'Artificial Intelligence', 'Signal Processing', 'General Mathematics', 'General Computer Science', 'General Computer Science', 'Computer Networks and Communications', 'Ecological Modeling', 'Information Systems', 'Software', 'Software', 'Computer Graphics and Computer-Aided Design', 'Control and Systems Engineering', 'Mechanical Engineering', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Software', 'Ecological Modeling', 'General Mathematics', 'Computer Science Applications', 'General Computer Science', 'Information Systems and Management', 'Computer Science Applications', 'Information Systems and Management', 'Human-Computer Interaction', 'Control and Systems Engineering', 'Artificial Intelligence', 'Software', 'Mechanical Engineering', 'General Mathematics', 'Control and Systems Engineering', 'Signal Processing', 'Computer Networks and Communications', 'Signal Processing', 'Computer Science Applications', 'Artificial Intelligence', 'Information Systems and Management', 'Electrical and Electronic Engineering', 'Control and Systems Engineering', 'General Computer Science', 'Information Systems', 'Computer Science Applications', 'Civil and Structural Engineering', 'Biochemistry', 'Safety, Risk, Reliability and Quality', 'Computer Science Applications', 'Human-Computer Interaction', 'Arts and Humanities (miscellaneous)', 'General Engineering', 'Computer Science Applications', 'Ecological Modeling', 'Information Systems', 'Applied Mathematics', 'Information Systems', 'Management Information Systems', 'General Computer Science', 'Computer Science Applications', 'Control and Systems Engineering', 'Computer Networks and Communications', 'Information Systems', 'Information Systems', 'Human-Computer Interaction', 'Computer Science Applications', 'Computer Science Applications', 'General Computer Science', 'Computer Networks and Communications', 'Information Systems', 'Civil and Structural Engineering', 'Computer Science Applications', 'Information Systems', 'Artificial Intelligence', 'Hardware and Architecture', 'Signal Processing', 'Information Systems', 'Civil and Structural Engineering', 'General Engineering', 'Artificial Intelligence', 'Software', 'Computer Science Applications', 'Computer Science Applications', 'Civil and Structural Engineering', 'Information Systems and Management', 'Artificial Intelligence', 'Computer Science Applications', 'Biochemistry', 'Artificial Intelligence', 'Computer Science Applications', 'Artificial Intelligence', 'Information Systems', 'General Engineering', 'Software', 'Civil and Structural Engineering', 'Computer Networks and  ...
#
# Cluster 9(N=110)
# ['Computer Science Applications', 'Computational Theory and Mathematics', 'Computer Science Applications', 'Information Systems', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'Computer Science Applications', 'Aerospace Engineering', 'General Computer Science', 'Computer Networks and Communications', 'Software', 'Electrical and Electronic Engineering', 'Control and Systems Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Aerospace Engineering', 'Aerospace Engineering', 'Computer Networks and Communications', 'Computer Science Applications', 'Computer Networks and Communications', 'Computer Science Applications', 'Mechanical Engineering', 'Aerospace Engineering', 'Computer Networks and Communications', 'Software', 'Signal Processing', 'Computer Science Applications', 'General Mathematics', 'Computer Science Applications', 'Aerospace Engineering', 'Artificial Intelligence', 'Computer Science Applications', 'Hardware and Architecture', 'General Mathematics', 'Arts and Humanities (miscellaneous)', 'Computer Science Applications', 'Applied Mathematics', 'Information Systems', 'Information Systems', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Information Systems', 'Safety, Risk, Reliability and Quality', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Signal Processing', 'Signal Processing', 'Computer Science Applications', 'Computer Science Applications', 'Software', 'Information Systems', 'General Computer Science', 'Computer Networks and Communications', 'Computer Science Applications', 'Aerospace Engineering', 'Information Systems', 'Software', 'Computer Science Applications', 'Signal Processing', 'Information Systems', 'Computer Science Applications', 'Computer Science Applications', 'Aerospace Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Networks and Communications', 'Information Systems', 'Computer Networks and Communications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Aerospace Engineering', 'General Computer Science', 'Computer Science Applications', 'Computer Networks and Communications', 'Aerospace Engineering', 'Information Systems', 'Computer Science Applications', 'Computer Science Applications', 'Computer Networks and Communications', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'General Computer Science', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Software', 'Computer Science Applications', 'Artificial Intelligence', 'Computer Networks and Communications', 'Computer Networks and Communications', 'Electrical and Electronic Engineering', 'Signal Processing', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Software', 'Artificial Intelligence']
#
# Cluster 10(N=116)
# ['Physical and Theoretical Chemistry', 'Biotechnology', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Information Systems', 'Biochemistry', 'Cellular and Molecular Neuroscience', 'Physical and Theoretical Chemistry', 'Biochemistry', 'Information Systems', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Cellular and Molecular Neuroscience', 'Information Systems', 'Biochemistry', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'General Biochemistry,Genetics and Molecular Biology', 'Biochemistry', 'Cellular and Molecular Neuroscience', 'General Biochemistry,Genetics and Molecular Biology', 'General Biochemistry,Genetics and Molecular Biology', 'Biochemistry', 'Biochemistry', 'Cellular and Molecular Neuroscience', 'Physical and Theoretical Chemistry', 'Electrical and Electronic Engineering', 'Cellular and Molecular Neuroscience', 'Physical and Theoretical Chemistry', 'Artificial Intelligence', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Information Systems', 'Physical and Theoretical Chemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Biochemistry', 'Biochemistry', 'General Biochemistry,Genetics and Molecular Biology', 'Biochemistry', 'General Biochemistry,Genetics and Molecular Biology', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Management Information Systems', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Biochemistry', 'Computer Science Applications', 'Signal Processing', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Information Systems', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Biochemistry', 'Information Systems', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Cellular and Molecular Neuroscience', 'Biochemistry', 'Biochemistry', 'Biochemistry', 'Biochemistry']
#
# Cluster 11(N=52)
# ['Computer Networks and Communications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Software', 'Information Systems', 'Aerospace Engineering', 'Information Systems', 'Information Systems', 'Information Systems', 'Computer Networks and Communications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Information Systems', 'Computer Science Applications', 'Computer Science Applications', 'Computer Networks and Communications', 'Computer Networks and Communications', 'Aerospace Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Software', 'Computers in Earth Sciences', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Networks and Communications', 'Computer Graphics and Computer-Aided Design', 'Computer Networks and Communications', 'Computer Science Applications', 'Applied Mathematics', 'Computer Science Applications', 'Information Systems', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Artificial Intelligence', 'Computer Science Applications', 'Computer Networks and Communications', 'Aerospace Engineering']
#
# Cluster 12(N=204)
# ['Computational Theory and Mathematics', 'Computer Science Applications', 'Software', 'Computer Science Applications', 'Artificial Intelligence', 'Applied Mathematics', 'Artificial Intelligence', 'Computer Graphics and Computer-Aided Design', 'Management Information Systems', 'Civil and Structural Engineering', 'Management Information Systems', 'Signal Processing', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Health Informatics', 'Management Information Systems', 'Computer Networks and Communications', 'Biotechnology', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Signal Processing', 'General Engineering', 'Information Systems', 'Control and Systems Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Management Information Systems', 'Civil and Structural Engineering', 'Artificial Intelligence', 'Computer Graphics and Computer-Aided Design', 'Signal Processing', 'Applied Mathematics', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Computer Graphics and Computer-Aided Design', 'Mechanical Engineering', 'Computer Science Applications', 'Software', 'Physical and Theoretical Chemistry', 'Artificial Intelligence', 'Artificial Intelligence', 'General Engineering', 'Management Information Systems', 'Hardware and Architecture', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Software', 'Civil and Structural Engineering', 'Management Information Systems', 'General Engineering', 'General Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Applied Mathematics', 'Computer Science Applications', 'Computer Vision and Pattern Recognition', 'Computer Science Applications', 'Software', 'General Engineering', 'Theoretical Computer Science', 'Software', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Computational Theory and Mathematics', 'Artificial Intelligence', 'General Engineering', 'Software', 'Software', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Theoretical Computer Science', 'Information Systems', 'Computer Science Applications', 'Computational Theory and Mathematics', 'Computer Graphics and Computer-Aided Design', 'Signal Processing', 'Artificial Intelligence', 'Computer Science Applications', 'Signal Processing', 'Civil and Structural Engineering', 'Control and Systems Engineering', 'Management Information Systems', 'Computer Science Applications', 'Management Information Systems', 'Control and Systems Engineering', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Computational Theory and Mathematics', 'Computer Science Applications', 'Applied Mathematics', 'Artificial Intelligence', 'Management Information Systems', 'Artificial Intelligence', 'Software', 'Computer Science Applications', 'Software', 'Management Information Systems', 'Computer Science Applications', 'Software', 'Electrical and Electronic Engineering', 'Management Information Systems', 'Artificial Intelligence', 'Computer Graphics and Computer-Aided Design', 'Information Systems and Management', 'General Engineering', 'Artificial Intelligence', 'Computer Science Applications', 'Computers in Earth Sciences', 'Information Systems', 'Aerospace Engineering', 'Signal Processing', 'Applied Mathematics', 'Artificial Intelligence', 'Software', 'Computer Science Applications', 'Artificial Intelligence', 'Artificial Intelligence', 'Computer Science Applications', 'Electrical and Electronic Engineering', 'Computer Graphics and Computer-Aided Design', 'Applied Mathematics', 'Signal Processing', 'Management Information Systems', 'Information Systems and Management', 'Computer Science Applications', 'Artificial Intelligence',  ...
#
# Cluster 13(N=176)
# ['Artificial Intelligence', 'Applied Mathematics', 'Artificial Intelligence', 'Computer Science Applications', 'Applied Mathematics', 'Computational Theory and Mathematics', 'Electrical and Electronic Engineering', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Artificial Intelligence', 'Computer Science Applications', 'Computer Science Applications', 'Artificial Intelligence', 'General Mathematics', 'Numerical Analysis', 'Computational Theory and Mathematics', 'Computer Science Applications', 'Control and Systems Engineering', 'Artificial Intelligence', 'Management Information Systems', nan, 'Artificial Intelligence', 'General Engineering', 'Applied Mathematics', 'Software', 'Software', 'General Mathematics', 'Artificial Intelligence', 'Computer Science Applications', 'Artificial Intelligence', 'Software', 'Cognitive Neuroscience', 'Information Systems', 'Software', 'Computational Theory and Mathematics', 'Computer Science Applications', 'Artificial Intelligence', 'Signal Processing', 'Aerospace Engineering', 'Software', 'Computer Science Applications', 'Computer Science Applications', 'Artificial Intelligence', 'Artificial Intelligence', 'Computer Graphics and Computer-Aided Design', 'Biochemistry', 'Artificial Intelligence', 'Artificial Intelligence', 'Information Systems and Management', 'General Computer Science', 'Artificial Intelligence', 'Artificial Intelligence', 'Computer Science Applications', 'Computer Science Applications', 'Information Systems and Management', 'Hardware and Architecture', 'Management Information Systems', 'Computational Theory and Mathematics', 'Computer Science Applications', 'Information Systems', 'Cognitive Neuroscience', 'Information Systems and Management', 'Computer Graphics and Computer-Aided Design', 'Information Systems', 'General Engineering', 'Electrical and Electronic Engineering', 'Software', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Hardware and Architecture', 'General Engineering', 'Applied Mathematics', 'Artificial Intelligence', 'Artificial Intelligence', 'Artificial Intelligence', 'Computer Science Applications', 'Numerical Analysis', 'Aerospace Engineering', 'Electrical and Electronic Engineering', 'Artificial Intelligence', 'Artificial Intelligence', 'Safety, Risk, Reliability and Quality', 'Computer Graphics and Computer-Aided Design', 'Biotechnology', 'Management Information Systems', 'Artificial Intelligence', 'Computational Theory and Mathematics', 'Computer Graphics and Computer-Aided Design', 'Artificial Intelligence', 'Biochemistry', 'Management Information Systems', 'Computer Science Applications', 'Artificial Intelligence', 'Computer Networks and Communications', 'Software', 'Management Information Systems', 'Computer Science Applications', 'Computer Science Applications', 'Management Information Systems', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Artificial Intelligence', 'Software', 'Computer Science Applications', 'Artificial Intelligence', 'General Engineering', 'Artificial Intelligence', 'Electrical and Electronic Engineering', 'Software', 'Information Systems', 'Ecological Modeling', 'Computer Science Applications', 'General Engineering', 'Applied Mathematics', 'Control and Systems Engineering', 'Information Systems', 'Computational Theory and Mathematics', 'Artificial Intelligence', 'Computer Science Applications', 'Information Systems', 'Software', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Management Information Systems', 'Electrical and Electronic Engineering', 'Signal Processing', 'Computer Networks and Communications', 'General Engineering', 'Management Information Systems', 'Artificial Intelligence', 'Computer Science Applications', 'Computer Science Applications', 'Applied Mathematics', 'Information Systems and Management', 'Information Systems and Management', 'Computer Science Applications', 'Artificial Intelli ...
#
# Cluster 14(N=167)
# ...
#
# Cluster 97(N=122)
# ['Computer Science Applications', 'Computer Science Applications', 'Applied Mathematics', 'Artificial Intelligence', 'Computer Science Applications', 'Signal Processing', 'Software', 'Computer Graphics and Computer-Aided Design', 'Signal Processing', 'Applied Mathematics', 'Computer Science Applications', 'Hardware and Architecture', 'Biochemistry', 'Computer Science Applications', 'Artificial Intelligence', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Artificial Intelligence', 'Computer Science Applications', 'Signal Processing', 'Artificial Intelligence', 'Signal Processing', 'Computer Science Applications', 'Computer Science Applications', 'Signal Processing', 'Artificial Intelligence', 'Signal Processing', 'Applied Mathematics', 'Artificial Intelligence', 'Signal Processing', 'Computer Science Applications', 'Safety, Risk, Reliability and Quality', 'Computers in Earth Sciences', 'Applied Mathematics', 'General Engineering', 'Artificial Intelligence', 'Computer Science Applications', 'Software', 'Signal Processing', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Applied Mathematics', 'Computer Science Applications', 'Computer Science Applications', 'Computer Graphics and Computer-Aided Design', 'Computer Graphics and Computer-Aided Design', 'Signal Processing', 'Computers in Earth Sciences', 'Information Systems', 'Control and Systems Engineering', 'Signal Processing', 'Signal Processing', 'Computer Science Applications', 'Computers in Earth Sciences', 'Signal Processing', 'Artificial Intelligence', 'Computer Science Applications', 'Artificial Intelligence', 'General Mathematics', 'Artificial Intelligence', 'Applied Mathematics', 'Applied Mathematics', 'Computer Science Applications', 'Computer Vision and Pattern Recognition', 'Computer Science Applications', 'Signal Processing', 'Computer Vision and Pattern Recognition', 'Signal Processing', 'Applied Mathematics', 'Control and Systems Engineering', 'Computer Science Applications', 'Computer Vision and Pattern Recognition', 'Signal Processing', 'Safety, Risk, Reliability and Quality', 'Artificial Intelligence', 'Computer Science Applications', 'Artificial Intelligence', 'Signal Processing', 'Signal Processing', 'General Mathematics', 'Signal Processing', 'Artificial Intelligence', 'Management Information Systems', 'Computer Science Applications', 'Applied Mathematics', 'Computer Networks and Communications', 'Applied Mathematics', 'Computer Graphics and Computer-Aided Design', 'Computer Graphics and Computer-Aided Design', 'Civil and Structural Engineering', 'Artificial Intelligence', 'Artificial Intelligence', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Artificial Intelligence', 'General Neuroscience', 'Artificial Intelligence', 'Software', 'Signal Processing', 'Signal Processing', 'Computer Science Applications', 'Signal Processing', 'Signal Processing', 'Electrical and Electronic Engineering', 'Artificial Intelligence', 'Computer Vision and Pattern Recognition', 'Artificial Intelligence', 'Computer Science Applications', 'General Mathematics', 'Artificial Intelligence', 'Computer Graphics and Computer-Aided Design', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Information Systems', 'Signal Processing', 'Signal Processing', 'Computer Graphics and Computer-Aided Design', 'Computer Vision and Pattern Recognition']
#
# Cluster 98(N=170)
# ['Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Hardware and Architecture', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Computational Mathematics', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Applied Mathematics', 'Computer Science Applications', 'Physical and Theoretical Chemistry', 'General Earth and Planetary Sciences', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Numerical Analysis', 'General Mathematics', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Applied Mathematics', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Cellular and Molecular Neuroscience', 'Hardware and Architecture', 'Computational Mathematics', 'Hardware and Architecture', 'Computational Mathematics', 'Hardware and Architecture', 'Hardware and Architecture', 'Numerical Analysis', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Applied Mathematics', 'General Computer Science', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Applied Mathematics', 'Computational Mathematics', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Computer Science Applications', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Computer Networks and Communications', 'Numerical Analysis', 'Physical and Theoretical Chemistry', 'Applied Mathematics', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Computer Science Applications', 'Hardware and Architecture', 'Numerical Analysis', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Numerical Analysis', 'Hardware and Architecture', 'Management Information Systems', 'Computational Mathematics', 'Numerical Analysis', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Computer Science Applications', 'Physical and Theoretical Chemistry', 'Civil and Structural Engineering', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'General Computer Science', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Hardware and Architecture', 'Hardware and Architecture', 'Physical and Theoretical Chemistry', 'Applied Mathematics', 'Hardware and Architecture', 'Applied Mathematics', 'Computational Mathematics', 'Hardware and Architecture', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physical and Theoretical Chemistry', 'Physi ...
#
# Cluster 99(N=123)
# ['Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Applied Mathematics', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Information Systems and Management', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'General Mathematics', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'General Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Signal Processing', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'General Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Information Systems', 'Applied Mathematics', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Control and Systems Engineering', 'Computer Science Applications', 'Information Systems', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Civil and Structural Engineering', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Software', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Computer Science Applications', 'Physical and Theoretical Chemistry', 'Computer Science Applications', 'Computer Science Applications']
#
# Cluster 100(N=152)
# ['Biotechnology', 'Computer Science Applications', 'Cellular and Molecular Neuroscience', 'Signal Processing', 'Computer Science Applications', 'Cellular and Molecular Neuroscience', 'Computer Science Applications', 'Cellular and Molecular Neuroscience', 'Signal Processing', 'Cellular and Molecular Neuroscience', 'Computer Science Applications', 'Health Informatics', 'Cognitive Neuroscience', 'Health Informatics', 'General Computer Science', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Electrical and Electronic Engineering', 'Computer Networks and Communications', 'Computer Networks and Communications', 'Computer Science Applications', 'General Neuroscience', 'Artificial Intelligence', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Applied Mathematics', 'Electrical and Electronic Engineering', 'Cellular and Molecular Neuroscience', 'Signal Processing', 'Applied Mathematics', 'Computer Networks and Communications', 'Applied Mathematics', 'Electrical and Electronic Engineering', 'Cognitive Neuroscience', 'Cellular and Molecular Neuroscience', 'Software', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Signal Processing', 'General Neuroscience', 'Computer Networks and Communications', 'Computer Networks and Communications', 'Signal Processing', 'Biotechnology', 'Computer Science Applications', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Computer Science Applications', 'Signal Processing', 'Computer Science Applications', 'Biotechnology', 'Management Information Systems', 'Information Systems', 'Software', 'Applied Mathematics', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Cognitive Neuroscience', 'Cognitive Neuroscience', 'General Computer Science', 'Biotechnology', 'Health Informatics', 'Artificial Intelligence', 'Cellular and Molecular Neuroscience', 'Computer Science Applications', 'Cellular and Molecular Neuroscience', 'Artificial Intelligence', 'Cellular and Molecular Neuroscience', 'Software', 'Electrical and Electronic Engineering', 'Cellular and Molecular Neuroscience', 'Computer Networks and Communications', 'Cognitive Neuroscience', 'Computer Science Applications', 'General Neuroscience', 'Cellular and Molecular Neuroscience', 'Biotechnology', 'Cellular and Molecular Neuroscience', 'Computer Networks and Communications', 'Management Information Systems', 'Computer Science Applications', 'Biotechnology', 'Cellular and Molecular Neuroscience', 'Applied Mathematics', 'Human-Computer Interaction', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Software', 'Electrical and Electronic Engineering', 'Computer Science Applications', 'Computer Networks and Communications', 'Electrical and Electronic Engineering', 'Electrical and Electronic Engineering', 'Software', 'Cellular and Molecular Neuroscience', 'Applied Mathematics', 'Biotechnology', 'Computer Networks and Communications', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Electrical and Electronic Engineering', 'Applied Mathematics', 'Cognitive Neuroscience', 'Artificial Intelligence', 'Cellular and Molecular Neuroscience', 'Software', 'Cellular and Molecular Neuroscience', 'Electrical and Electronic Engineering', 'Cellular and Molecular Neuroscience', 'Electrical and Electronic Engineering', 'Cellular and Molecular Neuroscience', 'Computer Science Applications', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Cellular and Molecular Neuroscience', 'Health Informatics', 'Control and Systems Engineering', 'Cellular and Molecular Neuroscience', 'Information Systems', 'Information Systems', 'Electrical and Electronic Engineering', 'Software', 'Cognitive Neuroscience', 'Applied Mathematics', 'Cellular and Molecular Neuroscience', 'Computer Science ...

# %%
for _i, _cluster in enumerate(scopus_2019_life.clustered_subjects):
    print("Cluster", _i + 1)
    _max_subject = ""
    _max_count = 0
    for _subject in set(_cluster):
        if _cluster.count(_subject) > _max_count:
            _max_count = _cluster.count(_subject)
            _max_subject = _subject
#         print("\t%s\t%d" % (_subject, _cluster.count(_subject)))
    print("\t%s\t%d" % (_max_subject, _max_count))
# Out:
# Cluster 1
# 	General Computer Science	34
# Cluster 2
# 	Computer Science Applications	22
# Cluster 3
# 	Computer Science Applications	14
# Cluster 4
# 	Electrical and Electronic Engineering	83
# Cluster 5
# 	Computer Science Applications	20
# 	Health Informatics	5
# 	Electrical and Electronic Engineering	14
# 	Applied Mathematics	9
# 	General Neuroscience	3
# 	Biotechnology	7
# 	Software	10
# 	General Physics and Astronomy	1
# 	General Computer Science	2
# 	Numerical Analysis	1
# 	Management Information Systems	2

# %%
_set_titles = set(scopus_2019_life.df_scopus[scopus_2019_life.df_scopus["DOI"].isin(scopus_2019_life.idx_papers)]["Title"])
for _i, _cluster in enumerate(scopus_2019_life.clustered_subjects):
    print("Cluster", _i + 1)
    _max_subject = ""
    _max_count = 0
    for _subject in set(_cluster):
        if _cluster.count(_subject) > _max_count:
            _max_count = _cluster.count(_subject)
            _max_subject = _subject
#         print("\t%s\t%d" % (_subject, _cluster.count(_subject)))
    print("\t%s\t%d" % (_max_subject, _max_count))
    _intersection = set(scopus_2019_life.clustered_titles[_i]).intersection(_set_titles)
    print("\t# intersection: %d" % len(_intersection))
    if len(_intersection):
        print("\t\t", _intersection)
# Out:
# Cluster 1
# 	General Computer Science	34
# 	# intersection: 0
# Cluster 2
# 	Computer Science Applications	22
# 	# intersection: 0
# Cluster 3
# 	Computer Science Applications	14
# 	# intersection: 1
# 		 {'An Evaluation of Depth and Size Perception on a Spherical Fish Tank Virtual Reality Display'}
# Cluster 4
# 	Electrical and Electronic Engineering	83
# 	# intersection: 0
# Cluster 5
# 	Computer Science Applications	20
# 	# intersection: 1
# 		 {'Smartphones reduce smiles between strangers'}
# Cluster 6
# 	Computer Science Applications	88
# 	# intersection: 0
# Cluster 7
# 	Electrical and Electronic Engineering	39
# 	# intersection: 1
# 		 {'Audio-Material Reconstruction for Virtualized Reality Using a Probabilistic Damping Model'}
# Cluster 8
# 	Computer Science Applications	22
# 	# intersection: 0
# Cluster 9
# 	Computer Science Applications	38
# 	# intersection: 1
# 		 {'AGRA: AI-augmented geographic routing approach for IoT-based incident-supporting applications'}
# Cluster 10
# 	Biochemistry	70
# 	# intersection: 1
# 		 {'Pattern recognition analysis on long noncoding RNAs: A tool for prediction in plants'}
# Cluster 11
# 	Computer Science Applications	27
# 	# intersection: 0
# Cluster 12
# 	Computer Science Applications	42
# 	# intersection: 0
# Cluster 13
# 	Artificial Intelligence	34
# 	# intersection: 0
# Cluster 14
# 	Software	32
# 	# intersection: 0
# Cluster 15
# 	Computer Science Applications	71
# 	# intersection: 0
# Cluster 16
# 	Computational Theory and Mathematics	27
# 	# intersection: 0
# Cluster 17
# 	General Computer Science	61
# 	# intersection: 3
# 		 {'Applying learning analytics to students’ interaction in business simulation games. The usefulness of learning analytics to know what students really learn', 'How instructors frame students’ interactions with educational technologies can enhance or reduce learning with multiple representations', 'Girls’ video gaming behaviour and undergraduate degree selection: A secondary data analysis approach'}
# Cluster 18
# 	Computer Science Applications	26
# 	# intersection: 0
# Cluster 19
# 	Software	18
# 	# intersection: 2
# 		 {'Adaptive Motion Planning Based on Vehicle Characteristics and Regulations for Off-Road UGVs', 'Origin-Destination Flow Maps in Immersive Environments'}
# Cluster 20
# 	Civil and Structural Engineering	27
# 	# intersection: 0
# Cluster 21
# 	Computer Science Applications	54
# 	# intersection: 1
# 		 {'High-performance liquid alloy patterning of epidermal strain sensors for local fine skin movement monitoring'}
# Cluster 22
# 	Software	46
# 	# intersection: 0
# Cluster 23
# 	Biochemistry	64
# 	# intersection: 1
# 		 {'Redundancy principle and the role of extreme statistics in molecular and cellular biology'}
# Cluster 24
# 	Control and Systems Engineering	36
# 	# intersection: 0
# Cluster 25
# 	Computer Science Applications	52
# 	# intersection: 2
# 		 {'A distributed, plug-n-play algorithm for multi-robot applications with a priori non-computable objective functions', 'TrackerBots: Autonomous unmanned aerial vehicle for real-time localization and tracking of multiple radio-tagged animals'}
# Cluster 26
# 	Signal Processing	19
# 	# intersection: 3
# 		 {'Locomotion in virtual reality for room scale tracked areas', 'Latent goal models for dynamic strategic interaction', 'Deep full-body motion network for a soft wearable motion sensing suit'}
# Cluster 27
# 	Computer Science Applications	25
# 	# intersection: 1
# 		 {'Digitization of music: Consumer adoption amidst piracy, unbundling, and rebundling'}
# Cluster 28
# 	Information Systems and Management	55
# 	# intersection: 0
# Cluster 29
# 	Computer Science Applications	13
# 	# intersection: 0
# Cluster 30
# 	Arts and Humanities (miscellaneous)	44
# 	# intersection: 3
# 		 {'Social media data and post-disaster recovery', 'Assessing binge-watching behaviors: Development and validation of the “Watching TV Series Motives” and “Binge-watching Engagement and Symptoms” questionnaires', 'The Internet and Facebook Usage on Academic Distraction of College Students'}
# Cluster 31
# 	Computer Science Applications	43
# 	# intersection: 1
# 		 {'Non-intrusive Sparse Subspace Learning for Parametrized Problems'}
# Cluster 32
# 	Artificial Intelligence	34
# 	# intersection: 0
# Cluster 33
# 	Computer Science Applications	26
# 	# intersection: 1
# 		 {'SGaze: A Data-Driven Eye-Head Coordination Model for Realtime Gaze Prediction'}
# Cluster 34
# 	Computer Science Applications	36
# 	# intersection: 0
# Cluster 35
# 	Applied Mathematics	20
# 	# intersection: 0
# Cluster 36
# 	Mechanical Engineering	14
# 	# intersection: 1
# 		 {'Pareto-Based Maintenance Decisions for Regional Railways with Uncertain Weld Conditions Using the Hilbert Spectrum of Axle Box Acceleration'}
# Cluster 37
# 	Computer Science Applications	22
# 	# intersection: 2
# 		 {'Motion Deblurring of Faces', 'BIM-Tracker: A model-based visual tracking approach for indoor localisation using a 3D building model'}
# Cluster 38
# 	Information Systems	14
# 	# intersection: 0
# Cluster 39
# 	Biochemistry	67
# 	# intersection: 1
# 		 {'IRIS-EDA: An integrated RNA-seq interpretation system for gene expression data analysis'}
# Cluster 40
# 	Computer Science Applications	35
# 	# intersection: 0
# Cluster 41
# 	Information Systems	25
# 	# intersection: 2
# 		 {'Ten simple rules towards healthier research labs', 'Dynamic BIM-augmented UAV safety inspection for water diversion project'}
# Cluster 42
# 	Computer Science Applications	29
# 	# intersection: 2
# 		 {'Visual Analysis of Aneurysm Data using Statistical Graphics', 'Thalia: Semantic search engine for biomedical abstracts'}
# Cluster 43
# 	Applied Mathematics	29
# 	# intersection: 0
# Cluster 44
# 	Computer Science Applications	38
# 	# intersection: 0
# Cluster 45
# 	Mechanical Engineering	38
# 	# intersection: 0
# Cluster 46
# 	Computer Science Applications	37
# 	# intersection: 1
# 		 {'Progress in context-aware recommender systems - An overview'}
# Cluster 47
# 	Computer Science Applications	20
# 	# intersection: 0
# Cluster 48
# 	Computer Networks and Communications	35
# 	# intersection: 1
# 		 {'A manifesto for future generation cloud computing: Research directions for the next decade'}
# Cluster 49
# 	Information Systems and Management	39
# 	# intersection: 0
# Cluster 50
# 	Aerospace Engineering	24
# 	# intersection: 0
# Cluster 51
# 	Aerospace Engineering	59
# 	# intersection: 0
# Cluster 52
# 	Information Systems and Management	29
# 	# intersection: 0
# Cluster 53
# 	Computer Science Applications	38
# 	# intersection: 0
# Cluster 54
# 	Electrical and Electronic Engineering	19
# 	# intersection: 1
# 		 {'Identification of avian flapping motion from non-volant winged dinosaurs based on modal effective mass analysis'}
# Cluster 55
# 	Computer Science Applications	37
# 	# intersection: 0
# Cluster 56
# 	Computer Science Applications	37
# 	# intersection: 0
# Cluster 57
# 	Cellular and Molecular Neuroscience	19
# 	# intersection: 1
# 		 {'Machine learning analysis of gene expression data reveals novel diagnostic and prognostic biomarkers and identifies therapeutic targets for soft tissue sarcomas'}
# Cluster 58
# 	Computer Science Applications	62
# 	# intersection: 9
# 		 {'Robotic Insertion of Flexible Needle in Deformable Structures Using Inverse Finite-Element Simulation', 'Automatic virtual impedance adaptation of a knee exoskeleton for personalized walking assistance', 'Sensor-based reactive navigation in unknown convex sphere worlds', 'Automatic Couplings with Mechanical Overload Protection for Modular Robots', 'Robot Learning System Based on Adaptive Neural Control and Dynamic Movement Primitives', 'Real-Time Robotic Manipulation of Cylindrical Objects in Dynamic Scenarios Through Elliptic Shape Primitives', 'Multi-goal motion planning using traveling salesman problem in belief space', 'Multi-robot rendezvous based on bearing-aided hierarchical tracking of network topology', 'Modeling interaction structure for robot imitation learning of human social behavior'}
# Cluster 59
# 	Control and Systems Engineering	66
# 	# intersection: 0
# Cluster 60
# 	Software	45
# 	# intersection: 1
# 		 {'Can atlas-based auto-segmentation ever be perfect? Insights from extreme value theory'}
# Cluster 61
# 	Cellular and Molecular Neuroscience	17
# 	# intersection: 0
# Cluster 62
# 	Cellular and Molecular Neuroscience	22
# 	# intersection: 0
# Cluster 63
# 	Computer Science Applications	31
# 	# intersection: 0
# Cluster 64
# 	Computer Science Applications	38
# 	# intersection: 0
# Cluster 65
# 	Computer Science Applications	43
# 	# intersection: 1
# 		 {'Federated machine learning: Concept and applications'}
# Cluster 66
# 	Civil and Structural Engineering	75
# 	# intersection: 0
# Cluster 67
# 	Civil and Structural Engineering	24
# 	# intersection: 1
# 		 {'Control of Nonprehensile Planar Rolling Manipulation: A Passivity-Based Approach'}
# Cluster 68
# 	General Earth and Planetary Sciences	66
# 	# intersection: 1
# 		 {'Operations research for sustainability assessment of products: A review'}
# Cluster 69
# 	Information Systems	25
# 	# intersection: 0
# Cluster 70
# 	Electrical and Electronic Engineering	21
# 	# intersection: 0
# Cluster 71
# 	Computer Science Applications	21
# 	# intersection: 0
# Cluster 72
# 	General Computer Science	56
# 	# intersection: 0
# Cluster 73
# 	Information Systems and Management	38
# 	# intersection: 0
# Cluster 74
# 	Artificial Intelligence	16
# 	# intersection: 0
# Cluster 75
# 	General Computer Science	60
# 	# intersection: 0
# Cluster 76
# 	Mechanical Engineering	44
# 	# intersection: 0
# Cluster 77
# 	Computer Science Applications	47
# 	# intersection: 0
# Cluster 78
# 	Applied Mathematics	54
# 	# intersection: 0
# Cluster 79
# 	Software	21
# 	# intersection: 0
# Cluster 80
# 	Arts and Humanities (miscellaneous)	38
# 	# intersection: 0
# Cluster 81
# 	Artificial Intelligence	19
# 	# intersection: 1
# 		 {'Computational Deglutition: Using Signal- and Image-Processing Methods to Understand Swallowing and Associated Disorders [Life Sciences]'}
# Cluster 82
# 	Computer Science Applications	47
# 	# intersection: 1
# 		 {'Ensemble Neural Networks (ENN): A gradient-free stochastic method'}
# Cluster 83
# 	Computer Science Applications	28
# 	# intersection: 0
# Cluster 84
# 	Computer Science Applications	17
# 	# intersection: 2
# 		 {'Robotic Skill Learning for Precision Assembly with Microscopic Vision and Force Feedback', 'In the shades of the uncanny valley: An experimental study of human–chatbot interaction'}
# Cluster 85
# 	Physical and Theoretical Chemistry	50
# 	# intersection: 2
# 		 {'EncoderMap: Dimensionality Reduction and Generation of Molecule Conformations', 'GFN2-xTB - An Accurate and Broadly Parametrized Self-Consistent Tight-Binding Quantum Chemical Method with Multipole Electrostatics and Density-Dependent Dispersion Contributions'}
# Cluster 86
# 	Computer Science Applications	66
# 	# intersection: 0
# Cluster 87
# 	Computer Science Applications	17
# 	# intersection: 1
# 		 {'Will TCP Work in mmWave 5G Cellular Networks?'}
# Cluster 88
# 	Artificial Intelligence	21
# 	# intersection: 1
# 		 {'Visual Analysis of Spatia-temporal Relations of Pairwise Attributes in Unsteady Flow'}
# Cluster 89
# 	Electrical and Electronic Engineering	44
# 	# intersection: 0
# Cluster 90
# 	Computer Graphics and Computer-Aided Design	43
# 	# intersection: 1
# 		 {'Perceptually Based Adaptive Motion Retargeting to Animate Real Objects by Light Projection'}
# Cluster 91
# 	Computer Science Applications	41
# 	# intersection: 0
# Cluster 92
# 	Artificial Intelligence	29
# 	# intersection: 0
# Cluster 93
# 	Computer Science Applications	27
# 	# intersection: 2
# 		 {'A stochastic program to evaluate disruption mitigation investments in the supply chain', 'A Switched Systems Approach to Path Following With Intermittent State Feedback'}
# Cluster 94
# 	Information Systems	21
# 	# intersection: 0
# Cluster 95
# 	Aerospace Engineering	37
# 	# intersection: 0
# Cluster 96
# 	General Computer Science	27
# 	# intersection: 0
# Cluster 97
# 	Computer Science Applications	30
# 	# intersection: 1
# 		 {'Smart brushing for parallel coordinates'}
# Cluster 98
# 	Physical and Theoretical Chemistry	99
# 	# intersection: 1
# 		 {'FermiSurfer: Fermi-surface viewer providing multiple representation schemes'}
# Cluster 99
# 	Computer Science Applications	106
# 	# intersection: 0
# Cluster 100
# 	Cellular and Molecular Neuroscience	40
# 	# intersection: 0
